# %% [markdown]
# ## Loading dataset

# %%
from beta_rec.datasets.dunnhumby import Dunnhumby
from beta_rec.data.sequential_data import SequentialData

dataset = Dunnhumby(min_u_c=30,min_i_c=20,min_o_c=10)
split_dataset = dataset.load_temporal_basket_split(test_rate=0.2)
data = SequentialData(split_dataset)
# Out:
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 1204057    | 1204057    | 1204057      | 1204057         | 1204057     |
# | nunique | 2351       | 11166      | 1            | 125058          | 152982      |
# +---------+------------+------------+--------------+-----------------+-------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 513526     | 513526     | 513526       | 513526          |
# | nunique | 2276       | 11138      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 525646     | 525646     | 525646       | 525646          |
# | nunique | 2299       | 11123      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 524724     | 524724     | 524724       | 524724          |
# | nunique | 2295       | 11116      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 512824     | 512824     | 512824       | 512824          |
# | nunique | 2273       | 11131      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table

# %% [markdown]
# ### Model config

# %%
config = {"config_file": "../configs/sasrec_default.json",
          "device":"gpu",
          "emb_dim":64,
          "num_blocks": 2,
          "num_heads": 2,
          "lr": 0.5,
          "dropout_rate":0.1
         }
# the 'config_file' key is required, that is used load a default config.
# Other keys can be specified to replace the default settings.

# %% [markdown]
# ### Model intialization and training

# %%
from beta_rec.recommenders import SASRec

model = SASRec(config)
model.train(data)
# Out:
# loading config file ../configs/sasrec_default.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +----+--------------------+----------+
# |    | keys               | values   |
# |----+--------------------+----------|
# |  0 | system:device      | gpu      |
# |  1 | model:emb_dim      | 64       |
# |  2 | model:num_blocks   | 2        |
# |  3 | model:num_heads    | 2        |
# |  4 | model:lr           | 0.5      |
# |  5 | model:dropout_rate | 0.1      |
# +----+--------------------+----------+
# --------------------------------------------------------------------------------
# logs will save in file: /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_220700_eqnxga .stdout.log .stderr.log
# 2021-01-24 22:07:00 [INFO]-
# Python version: 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# [GCC 7.3.0
# 2021-01-24 22:07:00 [INFO]-
# 2021-01-24 22:07:00 [INFO]-pytorch version: 1.7.1
# 2021-01-24 22:07:00 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_220700_eqnxga
# 2021-01-24 22:07:00 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_220700_eqnxga
# 2021-01-24 22:07:00 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/sasrec_result.csv
# 2021-01-24 22:07:00 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:07:00 [INFO]-System configs
# 2021-01-24 22:07:00 [INFO]-
# +----+----------------+-------------------------------------------------------------------------------------+
# |    | keys           | values                                                                              |
# |----+----------------+-------------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                   |
# |  1 | log_dir        | logs/                                                                               |
# |  2 | result_dir     | results/                                                                            |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                        |
# |  4 | checkpoint_dir | checkpoints/                                                                        |
# |  5 | dataset_dir    | datasets/                                                                           |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_220700_eqnxga        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                     |
# |  8 | device         | gpu                                                                                 |
# |  9 | seed           | 2020                                                                                |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                              |
# | 11 | k              | [5, 10, 20]                                                                         |
# | 12 | valid_metric   | ndcg                                                                                |
# | 13 | valid_k        | 10                                                                                  |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/sasrec_result.csv                         |
# | 15 | save_mode      | average                                                                             |
# | 16 | model_run_id   | SASRec_default_20210124_220700_eqnxga                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_220700_eqnxga        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_220700_eqnxga |
# +----+----------------+-------------------------------------------------------------------------------------
# 2021-01-24 22:07:00 [INFO]-
# 2021-01-24 22:07:00 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:07:00 [INFO]-Get a gpu with the most available memory : 0
# 2021-01-24 22:07:00 [INFO]-[Warning]: port 8003 was already in use.
# 2021-01-24 22:07:00 [INFO]-If you need to use prometheus, please check that port or specify another port number.
# 2021-01-24 22:07:00 [INFO]-Initializing test engine ...
# 2021-01-24 22:07:00 [INFO]-Get a gpu with the most available memory : 0
# 2021-01-24 22:07:00 [INFO]-{'system': {'root_dir': '/home/zm324/workspace/beta-recsys', 'log_dir': 'logs/', 'result_dir': 'results/', 'process_dir': '/home/zm324/workspace/beta-recsys/processes/', 'checkpoint_dir': 'checkpoints/', 'dataset_dir': 'datasets/', 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_220700_eqnxga', 'tune_dir': '/home/zm324/workspace/beta-recsys/tune_results/', 'device': 'gpu', 'seed': 2020, 'metrics': ['ndcg', 'precision', 'recall', 'map'], 'k': [5, 10, 20], 'valid_metric': 'ndcg', 'valid_k': 10, 'result_file': '/home/zm324/workspace/beta-recsys/results/sasrec_result.csv', 'save_mode': 'average', 'model_run_id': 'SASRec_default_20210124_220700_eqnxga', 'log_file': '/home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_220700_eqnxga', 'model_save_dir': '/home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_220700_eqnxga'}, 'dataset': {'dataset': 'ml_100k', 'data_split': 'leave_one_out', 'test_rate': 0.2, 'download': False, 'random': False, 'by_user': False, 'n_test': 10, 'n_negative': 100, 'result_col': ['dataset', 'data_split', 'test_rate', 'n_negative']}, 'model': {'model': 'SASRec', 'config_id': 'default', 'emb_dim': 64, 'num_blocks': 2, 'num_heads': 2, 'maxlen': 200, 'lr': 0.5, 'batch_size': 128, 'batch_eval': True, 'dropout_rate': 0.1, 'optimizer': 'adam', 'l2_emb': 0.1, 'max_epoch': 200, 'max_n_update': 20, 'save_name': 'sasrec.model', 'result_col': ['model', 'emb_dim', 'batch_size', 'maxlen', 'optimizer', 'lr', 'l2_emb'], 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_220700_eqnxga', 'device_str': 'cuda:0', 'n_users': 2351, 'n_items': 11166}, 'tunable': [{'name': 'emb_dim', 'type': 'choice', 'values': [32, 64]}, {'name': 'lr', 'type': 'choice', 'values': [1, 0.5, 0.3, 0.1, 0.001]}, {'name': 'lrnum_heads', 'type': 'choice', 'values': [1, 2]}, {'name': 'l2_emb', 'type': 'choice', 'values': [0.0001, 0.001, 0.01, 0.1, 1]}], 'device_str': 'cuda:0'}
# 2021-01-24 22:07:00 [INFO]-Setting device for torch_engine cuda:0
# 2021-01-24 22:07:02 [INFO]-
# SASRec(
#   (item_emb): Embedding(11167, 64, padding_idx=0)
#   (pos_emb): Embedding(200, 64)
#   (emb_dropout): Dropout(p=0.1, inplace=False)
#   (attention_layernorms): ModuleList(
#     (0): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     (1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#   )
#   (attention_layers): ModuleList(
#     (0): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=64, out_features=64, bias=True)
#     )
#     (1): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (forward_layernorms): ModuleList(
#     (0): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     (1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#   )
#   (forward_layers): ModuleList(
#     (0): PointWiseFeedForward(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#       (conv2): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (dropout2): Dropout(p=0.1, inplace=False)
#     )
#     (1): PointWiseFeedForward(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#       (conv2): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (dropout2): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (last_layernorm): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#
# 2021-01-24 22:07:02 [INFO]-
#   0%|          | 0/200 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-01-24 22:07:06 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:07:07 [INFO]-[Training Epoch 0], Loss 654.9717082977295
#   0%|          | 1/200 [00:14<49:40, 14.98s/it]Epoch 1 starts !
# 2021-01-24 22:07:21 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:07:42 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 22:07:42 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:07:42 [INFO]-performance on validation at epoch 0
# 2021-01-24 22:07:42 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.455067  |
# |  1 | precision@10 | 0.45341   |
# |  2 | recall@10    | 0.0512384 |
# |  3 | map@10       | 0.0283395 |
# +----+--------------+-----------
# 2021-01-24 22:07:42 [INFO]-
# 2021-01-24 22:07:42 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:07:42 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:07:42 [INFO]-performance on testing at epoch 0
# 2021-01-24 22:07:42 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.475543  |
# |  1 | precision@10 | 0.474771  |
# |  2 | recall@10    | 0.0523229 |
# |  3 | map@10       | 0.0296607 |
# +----+--------------+-----------
# 2021-01-24 22:07:42 [INFO]-
# 2021-01-24 22:07:42 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:07:42 [INFO]-Execute [train_eval_worker] method costing 20629.12 ms
# 2021-01-24 22:07:42 [INFO]-[Training Epoch 1], Loss 190.03960132598877
#   1%|1         | 2/200 [00:50<1:09:19, 21.01s/it]Epoch 2 starts !
# 2021-01-24 22:07:56 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:08:17 [INFO]-number of epochs that have no update 1
# 2021-01-24 22:08:17 [INFO]-Execute [train_eval_worker] method costing 20718.34 ms
# 2021-01-24 22:08:17 [INFO]-[Training Epoch 2], Loss 105.32343578338623
#   2%|1         | 3/200 [01:25<1:22:56, 25.26s/it]Epoch 3 starts !
# 2021-01-24 22:08:31 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:08:52 [INFO]-Current testEngine.best_valid_performance 0.45506732020598184
# 2021-01-24 22:08:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:08:52 [INFO]-performance on validation at epoch 2
# 2021-01-24 22:08:52 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.464139  |
# |  1 | precision@10 | 0.458821  |
# |  2 | recall@10    | 0.0523602 |
# |  3 | map@10       | 0.0299587 |
# +----+--------------+-----------
# 2021-01-24 22:08:52 [INFO]-
# 2021-01-24 22:08:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:08:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:08:52 [INFO]-performance on testing at epoch 2
# 2021-01-24 22:08:52 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.47048  |
# |  1 | precision@10 | 0.467582 |
# |  2 | recall@10    | 0.05097  |
# |  3 | map@10       | 0.028669 |
# +----+--------------+----------
# 2021-01-24 22:08:52 [INFO]-
# 2021-01-24 22:08:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:08:52 [INFO]-Execute [train_eval_worker] method costing 20751.57 ms
# 2021-01-24 22:08:52 [INFO]-[Training Epoch 3], Loss 97.14342880249023
#   2%|2         | 4/200 [02:01<1:32:57, 28.46s/it]Epoch 4 starts !
# 2021-01-24 22:09:07 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:09:28 [INFO]-Current testEngine.best_valid_performance 0.46413870054720224
# 2021-01-24 22:09:28 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:09:28 [INFO]-performance on validation at epoch 3
# 2021-01-24 22:09:28 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.466082  |
# |  1 | precision@10 | 0.46674   |
# |  2 | recall@10    | 0.0531481 |
# |  3 | map@10       | 0.0294932 |
# +----+--------------+-----------
# 2021-01-24 22:09:28 [INFO]-
# 2021-01-24 22:09:28 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:09:28 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:09:28 [INFO]-performance on testing at epoch 3
# 2021-01-24 22:09:28 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.490637  |
# |  1 | precision@10 | 0.490327  |
# |  2 | recall@10    | 0.0539562 |
# |  3 | map@10       | 0.0310937 |
# +----+--------------+-----------
# 2021-01-24 22:09:28 [INFO]-
# 2021-01-24 22:09:28 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:09:28 [INFO]-Execute [train_eval_worker] method costing 21089.98 ms
# 2021-01-24 22:09:29 [INFO]-[Training Epoch 4], Loss 90.11597633361816
#   2%|2         | 5/200 [02:36<1:39:29, 30.61s/it]Epoch 5 starts !
# 2021-01-24 22:09:43 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:10:04 [INFO]-number of epochs that have no update 1
# 2021-01-24 22:10:04 [INFO]-Execute [train_eval_worker] method costing 21109.47 ms
# 2021-01-24 22:10:04 [INFO]-[Training Epoch 5], Loss 79.99214744567871
#   3%|3         | 6/200 [03:12<1:44:13, 32.23s/it]Epoch 6 starts !
# 2021-01-24 22:10:19 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:10:40 [INFO]-number of epochs that have no update 2
# 2021-01-24 22:10:40 [INFO]-Execute [train_eval_worker] method costing 20507.08 ms
# 2021-01-24 22:10:40 [INFO]-[Training Epoch 6], Loss 78.43296575546265
#   4%|3         | 7/200 [03:47<1:46:22, 33.07s/it]Epoch 7 starts !
# 2021-01-24 22:10:54 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:11:15 [INFO]-number of epochs that have no update 3
# 2021-01-24 22:11:15 [INFO]-Execute [train_eval_worker] method costing 20607.26 ms
# 2021-01-24 22:11:15 [INFO]-[Training Epoch 7], Loss 75.31998777389526
#   4%|4         | 8/200 [04:23<1:47:55, 33.73s/it]Epoch 8 starts !
# 2021-01-24 22:11:29 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:11:50 [INFO]-number of epochs that have no update 4
# 2021-01-24 22:11:50 [INFO]-Execute [train_eval_worker] method costing 20675.72 ms
# 2021-01-24 22:11:50 [INFO]-[Training Epoch 8], Loss 74.20085144042969
#   4%|4         | 9/200 [04:58<1:48:39, 34.13s/it]Epoch 9 starts !
# 2021-01-24 22:12:04 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:12:25 [INFO]-number of epochs that have no update 5
# 2021-01-24 22:12:25 [INFO]-Execute [train_eval_worker] method costing 20579.79 ms
# 2021-01-24 22:12:25 [INFO]-[Training Epoch 9], Loss 71.64689135551453
#   5%|5         | 10/200 [05:32<1:48:42, 34.33s/it]Epoch 10 starts !
# 2021-01-24 22:12:39 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:13:00 [INFO]-number of epochs that have no update 6
# 2021-01-24 22:13:00 [INFO]-Execute [train_eval_worker] method costing 20449.67 ms
# 2021-01-24 22:13:00 [INFO]-[Training Epoch 10], Loss 70.26016736030579
#   6%|5         | 11/200 [06:07<1:48:48, 34.54s/it]Epoch 11 starts !
# 2021-01-24 22:13:14 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:13:35 [INFO]-number of epochs that have no update 7
# 2021-01-24 22:13:35 [INFO]-Execute [train_eval_worker] method costing 20702.38 ms
# 2021-01-24 22:13:35 [INFO]-[Training Epoch 11], Loss 71.0868182182312
#   6%|6         | 12/200 [06:43<1:48:41, 34.69s/it]Epoch 12 starts !
# 2021-01-24 22:13:49 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:14:10 [INFO]-number of epochs that have no update 8
# 2021-01-24 22:14:10 [INFO]-Execute [train_eval_worker] method costing 20301.29 ms
# 2021-01-24 22:14:10 [INFO]-[Training Epoch 12], Loss 74.52283334732056
#   6%|6         | 13/200 [07:17<1:48:11, 34.71s/it]Epoch 13 starts !
# 2021-01-24 22:14:24 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:14:44 [INFO]-number of epochs that have no update 9
# 2021-01-24 22:14:44 [INFO]-Execute [train_eval_worker] method costing 20350.89 ms
# 2021-01-24 22:14:45 [INFO]-[Training Epoch 13], Loss 72.74958419799805
#   7%|7         | 14/200 [07:52<1:47:40, 34.73s/it]Epoch 14 starts !
# 2021-01-24 22:14:59 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:15:19 [INFO]-number of epochs that have no update 10
# 2021-01-24 22:15:19 [INFO]-Execute [train_eval_worker] method costing 20604.05 ms
# 2021-01-24 22:15:20 [INFO]-[Training Epoch 14], Loss 76.42528104782104
#   8%|7         | 15/200 [08:27<1:47:16, 34.79s/it]Epoch 15 starts !
# 2021-01-24 22:15:34 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:15:54 [INFO]-Current testEngine.best_valid_performance 0.46608211351447026
# 2021-01-24 22:15:54 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:15:54 [INFO]-performance on validation at epoch 14
# 2021-01-24 22:15:54 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.468043  |
# |  1 | precision@10 | 0.458953  |
# |  2 | recall@10    | 0.0539992 |
# |  3 | map@10       | 0.030843  |
# +----+--------------+-----------
# 2021-01-24 22:15:54 [INFO]-
# 2021-01-24 22:15:54 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:15:54 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:15:54 [INFO]-performance on testing at epoch 14
# 2021-01-24 22:15:54 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.48657   |
# |  1 | precision@10 | 0.480741  |
# |  2 | recall@10    | 0.0533694 |
# |  3 | map@10       | 0.0306021 |
# +----+--------------+-----------
# 2021-01-24 22:15:54 [INFO]-
# 2021-01-24 22:15:54 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:15:54 [INFO]-Execute [train_eval_worker] method costing 20563.81 ms
# 2021-01-24 22:15:55 [INFO]-[Training Epoch 15], Loss 72.34950971603394
#   8%|8         | 16/200 [09:02<1:46:50, 34.84s/it]Epoch 16 starts !
# 2021-01-24 22:16:09 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:16:29 [INFO]-number of epochs that have no update 1
# 2021-01-24 22:16:29 [INFO]-Execute [train_eval_worker] method costing 20645.67 ms
# 2021-01-24 22:16:30 [INFO]-[Training Epoch 16], Loss 70.2451593875885
#   8%|8         | 17/200 [09:38<1:47:13, 35.16s/it]Epoch 17 starts !
# 2021-01-24 22:16:45 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:05 [INFO]-number of epochs that have no update 2
# 2021-01-24 22:17:05 [INFO]-Execute [train_eval_worker] method costing 20678.23 ms
# 2021-01-24 22:17:06 [INFO]-[Training Epoch 17], Loss 74.12972617149353
#   9%|9         | 18/200 [10:14<1:47:10, 35.33s/it]Epoch 18 starts !
# 2021-01-24 22:17:20 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:41 [INFO]-number of epochs that have no update 3
# 2021-01-24 22:17:41 [INFO]-Execute [train_eval_worker] method costing 20562.79 ms
# 2021-01-24 22:17:41 [INFO]-[Training Epoch 18], Loss 75.13797879219055
#  10%|9         | 19/200 [10:49<1:46:57, 35.46s/it]Epoch 19 starts !
# 2021-01-24 22:17:56 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:18:17 [INFO]-number of epochs that have no update 4
# 2021-01-24 22:18:17 [INFO]-Execute [train_eval_worker] method costing 20496.38 ms
# 2021-01-24 22:18:17 [INFO]-[Training Epoch 19], Loss 72.87840247154236
#  10%|#         | 20/200 [11:25<1:46:26, 35.48s/it]Epoch 20 starts !
# 2021-01-24 22:18:32 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:18:52 [INFO]-number of epochs that have no update 5
# 2021-01-24 22:18:52 [INFO]-Execute [train_eval_worker] method costing 20662.75 ms
# 2021-01-24 22:18:53 [INFO]-[Training Epoch 20], Loss 73.6503734588623
#  10%|#         | 21/200 [12:01<1:46:01, 35.54s/it]Epoch 21 starts !
# 2021-01-24 22:19:07 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:19:28 [INFO]-number of epochs that have no update 6
# 2021-01-24 22:19:28 [INFO]-Execute [train_eval_worker] method costing 20739.23 ms
# 2021-01-24 22:19:28 [INFO]-[Training Epoch 21], Loss 73.24673390388489
#  11%|#1        | 22/200 [12:36<1:45:21, 35.52s/it]Epoch 22 starts !
# 2021-01-24 22:19:43 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:03 [INFO]-number of epochs that have no update 7
# 2021-01-24 22:20:03 [INFO]-Execute [train_eval_worker] method costing 20738.18 ms
# 2021-01-24 22:20:04 [INFO]-[Training Epoch 22], Loss 73.54260635375977
#  12%|#1        | 23/200 [13:11<1:44:44, 35.50s/it]Epoch 23 starts !
# 2021-01-24 22:20:18 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:39 [INFO]-Current testEngine.best_valid_performance 0.46804294657982976
# 2021-01-24 22:20:39 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:39 [INFO]-performance on validation at epoch 22
# 2021-01-24 22:20:39 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.469532  |
# |  1 | precision@10 | 0.463792  |
# |  2 | recall@10    | 0.0527231 |
# |  3 | map@10       | 0.0295957 |
# +----+--------------+-----------
# 2021-01-24 22:20:39 [INFO]-
# 2021-01-24 22:20:39 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:39 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:39 [INFO]-performance on testing at epoch 22
# 2021-01-24 22:20:39 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.472807  |
# |  1 | precision@10 | 0.467669  |
# |  2 | recall@10    | 0.0512008 |
# |  3 | map@10       | 0.0291092 |
# +----+--------------+-----------
# 2021-01-24 22:20:39 [INFO]-
# 2021-01-24 22:20:39 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:39 [INFO]-Execute [train_eval_worker] method costing 20864.50 ms
# 2021-01-24 22:20:39 [INFO]-[Training Epoch 23], Loss 79.6993727684021
#  12%|#2        | 24/200 [13:47<1:44:31, 35.64s/it]Epoch 24 starts !
# 2021-01-24 22:20:54 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:21:15 [INFO]-number of epochs that have no update 1
# 2021-01-24 22:21:15 [INFO]-Execute [train_eval_worker] method costing 20787.34 ms
# 2021-01-24 22:21:15 [INFO]-[Training Epoch 24], Loss 108.55537033081055
#  12%|#2        | 25/200 [14:23<1:43:39, 35.54s/it]Epoch 25 starts !
# 2021-01-24 22:21:29 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:21:50 [INFO]-Current testEngine.best_valid_performance 0.46953225154054806
# 2021-01-24 22:21:50 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:21:50 [INFO]-performance on validation at epoch 24
# 2021-01-24 22:21:50 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.471238  |
# |  1 | precision@10 | 0.469028  |
# |  2 | recall@10    | 0.0540637 |
# |  3 | map@10       | 0.0304806 |
# +----+--------------+-----------
# 2021-01-24 22:21:50 [INFO]-
# 2021-01-24 22:21:50 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:21:50 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:21:50 [INFO]-performance on testing at epoch 24
# 2021-01-24 22:21:50 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.481619  |
# |  1 | precision@10 | 0.480828  |
# |  2 | recall@10    | 0.0525631 |
# |  3 | map@10       | 0.0298865 |
# +----+--------------+-----------
# 2021-01-24 22:21:50 [INFO]-
# 2021-01-24 22:21:50 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:21:50 [INFO]-Execute [train_eval_worker] method costing 20828.47 ms
# 2021-01-24 22:21:51 [INFO]-[Training Epoch 25], Loss 145.4292984008789
#  13%|#3        | 26/200 [14:58<1:43:05, 35.55s/it]Epoch 26 starts !
# 2021-01-24 22:22:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:26 [INFO]-Current testEngine.best_valid_performance 0.4712377843468932
# 2021-01-24 22:22:26 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:26 [INFO]-performance on validation at epoch 25
# 2021-01-24 22:22:26 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.472935  |
# |  1 | precision@10 | 0.470172  |
# |  2 | recall@10    | 0.054044  |
# |  3 | map@10       | 0.0305362 |
# +----+--------------+-----------
# 2021-01-24 22:22:26 [INFO]-
# 2021-01-24 22:22:26 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:26 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:26 [INFO]-performance on testing at epoch 25
# 2021-01-24 22:22:26 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.485367  |
# |  1 | precision@10 | 0.484139  |
# |  2 | recall@10    | 0.0534716 |
# |  3 | map@10       | 0.0301812 |
# +----+--------------+-----------
# 2021-01-24 22:22:26 [INFO]-
# 2021-01-24 22:22:26 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:26 [INFO]-Execute [train_eval_worker] method costing 20860.75 ms
# 2021-01-24 22:22:26 [INFO]-[Training Epoch 26], Loss 120.50204372406006
#  14%|#3        | 27/200 [15:34<1:42:23, 35.51s/it]Epoch 27 starts !
# 2021-01-24 22:22:40 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:01 [INFO]-number of epochs that have no update 1
# 2021-01-24 22:23:01 [INFO]-Execute [train_eval_worker] method costing 20649.71 ms
# 2021-01-24 22:23:02 [INFO]-[Training Epoch 27], Loss 97.5991063117981
#  14%|#4        | 28/200 [16:09<1:41:31, 35.42s/it]Epoch 28 starts !
# 2021-01-24 22:23:16 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:36 [INFO]-Current testEngine.best_valid_performance 0.47293518056617767
# 2021-01-24 22:23:36 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:36 [INFO]-performance on validation at epoch 27
# 2021-01-24 22:23:36 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.479651  |
# |  1 | precision@10 | 0.475495  |
# |  2 | recall@10    | 0.0539906 |
# |  3 | map@10       | 0.0306793 |
# +----+--------------+-----------
# 2021-01-24 22:23:36 [INFO]-
# 2021-01-24 22:23:36 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:36 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:36 [INFO]-performance on testing at epoch 27
# 2021-01-24 22:23:36 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.497498  |
# |  1 | precision@10 | 0.492549  |
# |  2 | recall@10    | 0.0557648 |
# |  3 | map@10       | 0.0322515 |
# +----+--------------+-----------
# 2021-01-24 22:23:36 [INFO]-
# 2021-01-24 22:23:36 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:36 [INFO]-Execute [train_eval_worker] method costing 20718.43 ms
# 2021-01-24 22:23:37 [INFO]-[Training Epoch 28], Loss 93.68703889846802
#  14%|#4        | 29/200 [16:44<1:40:42, 35.33s/it]Epoch 29 starts !
# 2021-01-24 22:23:51 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:24:12 [INFO]-number of epochs that have no update 1
# 2021-01-24 22:24:12 [INFO]-Execute [train_eval_worker] method costing 20710.86 ms
# 2021-01-24 22:24:12 [INFO]-[Training Epoch 29], Loss 208.95141887664795
#  15%|#5        | 30/200 [17:19<1:40:10, 35.35s/it]Epoch 30 starts !
# 2021-01-24 22:24:26 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:24:47 [INFO]-number of epochs that have no update 2
# 2021-01-24 22:24:47 [INFO]-Execute [train_eval_worker] method costing 20779.65 ms
# 2021-01-24 22:24:47 [INFO]-[Training Epoch 30], Loss 268.35210037231445
#  16%|#5        | 31/200 [17:55<1:39:34, 35.35s/it]Epoch 31 starts !
# 2021-01-24 22:25:02 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:25:22 [INFO]-number of epochs that have no update 3
# 2021-01-24 22:25:22 [INFO]-Execute [train_eval_worker] method costing 20881.71 ms
# 2021-01-24 22:25:23 [INFO]-[Training Epoch 31], Loss 248.50949382781982
#  16%|#6        | 32/200 [18:30<1:38:56, 35.34s/it]Epoch 32 starts !
# 2021-01-24 22:25:37 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:25:58 [INFO]-number of epochs that have no update 4
# 2021-01-24 22:25:58 [INFO]-Execute [train_eval_worker] method costing 20884.83 ms
# 2021-01-24 22:25:58 [INFO]-[Training Epoch 32], Loss 222.73810577392578
#  16%|#6        | 33/200 [19:05<1:38:19, 35.33s/it]Epoch 33 starts !
# 2021-01-24 22:26:12 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:26:33 [INFO]-number of epochs that have no update 5
# 2021-01-24 22:26:33 [INFO]-Execute [train_eval_worker] method costing 20825.99 ms
# 2021-01-24 22:26:33 [INFO]-[Training Epoch 33], Loss 197.2935848236084
#  17%|#7        | 34/200 [19:41<1:37:59, 35.42s/it]Epoch 34 starts !
# 2021-01-24 22:26:48 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:27:08 [INFO]-number of epochs that have no update 6
# 2021-01-24 22:27:08 [INFO]-Execute [train_eval_worker] method costing 20541.31 ms
# 2021-01-24 22:27:09 [INFO]-[Training Epoch 34], Loss 178.18708610534668
#  18%|#7        | 35/200 [20:16<1:37:20, 35.40s/it]Epoch 35 starts !
# 2021-01-24 22:27:23 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:27:44 [INFO]-number of epochs that have no update 7
# 2021-01-24 22:27:44 [INFO]-Execute [train_eval_worker] method costing 20596.13 ms
# 2021-01-24 22:27:44 [INFO]-[Training Epoch 35], Loss 233.07136344909668
#  18%|#8        | 36/200 [20:52<1:37:08, 35.54s/it]Epoch 36 starts !
# 2021-01-24 22:27:59 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:28:20 [INFO]-number of epochs that have no update 8
# 2021-01-24 22:28:20 [INFO]-Execute [train_eval_worker] method costing 20757.05 ms
# 2021-01-24 22:28:20 [INFO]-[Training Epoch 36], Loss 274.47949409484863
#  18%|#8        | 37/200 [21:28<1:36:46, 35.62s/it]Epoch 37 starts !
# 2021-01-24 22:28:35 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:28:55 [INFO]-number of epochs that have no update 9
# 2021-01-24 22:28:55 [INFO]-Execute [train_eval_worker] method costing 20659.05 ms
# 2021-01-24 22:28:56 [INFO]-[Training Epoch 37], Loss 297.5423765182495
#  19%|#9        | 38/200 [22:04<1:36:24, 35.71s/it]Epoch 38 starts !
# 2021-01-24 22:29:11 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:29:32 [INFO]-number of epochs that have no update 10
# 2021-01-24 22:29:32 [INFO]-Execute [train_eval_worker] method costing 20840.45 ms
# 2021-01-24 22:29:32 [INFO]-[Training Epoch 38], Loss 370.67327308654785
#  20%|#9        | 39/200 [22:40<1:36:15, 35.87s/it]Epoch 39 starts !
# 2021-01-24 22:29:47 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:30:08 [INFO]-number of epochs that have no update 11
# 2021-01-24 22:30:08 [INFO]-Execute [train_eval_worker] method costing 20845.35 ms
# 2021-01-24 22:30:08 [INFO]-[Training Epoch 39], Loss 368.48035430908203
#  20%|##        | 40/200 [23:16<1:35:41, 35.88s/it]Epoch 40 starts !
# 2021-01-24 22:30:23 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:30:44 [INFO]-number of epochs that have no update 12
# 2021-01-24 22:30:44 [INFO]-Execute [train_eval_worker] method costing 20791.43 ms
# 2021-01-24 22:30:44 [INFO]-[Training Epoch 40], Loss 348.22205924987793
#  20%|##        | 41/200 [23:52<1:34:58, 35.84s/it]Epoch 41 starts !
# 2021-01-24 22:30:59 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:31:19 [INFO]-number of epochs that have no update 13
# 2021-01-24 22:31:19 [INFO]-Execute [train_eval_worker] method costing 20750.61 ms
# 2021-01-24 22:31:20 [INFO]-[Training Epoch 41], Loss 332.2136173248291
#  21%|##1       | 42/200 [24:28<1:34:23, 35.85s/it]Epoch 42 starts !
# 2021-01-24 22:31:35 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:31:55 [INFO]-number of epochs that have no update 14
# 2021-01-24 22:31:55 [INFO]-Execute [train_eval_worker] method costing 20823.52 ms
# 2021-01-24 22:31:56 [INFO]-[Training Epoch 42], Loss 324.0590076446533
#  22%|##1       | 43/200 [25:04<1:33:54, 35.89s/it]Epoch 43 starts !
# 2021-01-24 22:32:11 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:32:31 [INFO]-number of epochs that have no update 15
# 2021-01-24 22:32:31 [INFO]-Execute [train_eval_worker] method costing 20610.49 ms
# 2021-01-24 22:32:32 [INFO]-[Training Epoch 43], Loss 320.06267738342285
#  22%|##2       | 44/200 [25:40<1:33:23, 35.92s/it]Epoch 44 starts !
# 2021-01-24 22:32:47 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:33:07 [INFO]-number of epochs that have no update 16
# 2021-01-24 22:33:07 [INFO]-Execute [train_eval_worker] method costing 20641.57 ms
# 2021-01-24 22:33:08 [INFO]-[Training Epoch 44], Loss 323.38488388061523
#  22%|##2       | 45/200 [26:16<1:32:57, 35.98s/it]Epoch 45 starts !
# 2021-01-24 22:33:23 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:33:43 [INFO]-number of epochs that have no update 17
# 2021-01-24 22:33:43 [INFO]-Execute [train_eval_worker] method costing 20620.55 ms
# 2021-01-24 22:33:44 [INFO]-[Training Epoch 45], Loss 314.04393005371094
#  23%|##3       | 46/200 [26:52<1:32:27, 36.03s/it]Epoch 46 starts !
# 2021-01-24 22:33:59 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:34:20 [INFO]-number of epochs that have no update 18
# 2021-01-24 22:34:20 [INFO]-Execute [train_eval_worker] method costing 20778.56 ms
# 2021-01-24 22:34:20 [INFO]-[Training Epoch 46], Loss 302.3801975250244
#  24%|##3       | 47/200 [27:28<1:31:58, 36.07s/it]Epoch 47 starts !
# 2021-01-24 22:34:35 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:34:56 [INFO]-number of epochs that have no update 19
# 2021-01-24 22:34:56 [INFO]-Execute [train_eval_worker] method costing 20657.84 ms
# 2021-01-24 22:34:56 [INFO]-[Training Epoch 47], Loss 295.9266929626465
#  24%|##4       | 48/200 [28:04<1:31:21, 36.06s/it]Epoch 48 starts !
# 2021-01-24 22:35:11 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:35:31 [INFO]-number of epochs that have no update 20
# 2021-01-24 22:35:31 [INFO]-Execute [train_eval_worker] method costing 20444.62 ms
# 2021-01-24 22:35:32 [INFO]-[Training Epoch 48], Loss 289.99765396118164
#  24%|##4       | 49/200 [28:40<1:30:36, 36.00s/it]Epoch 49 starts !
# 2021-01-24 22:35:47 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:35:47 [INFO]-Early stop criterion triggered, no performance update for 20 times
#  24%|##4       | 49/200 [28:40<1:28:22, 35.11s/it]
# 2021-01-24 22:35:47 [INFO]-Program running time:1724 seconds
# {'valid_metric': 0.4796510309913736,
#  'model_save_dir': '/home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_220700_eqnxga/sasrec.model'}
# 2021-01-24 22:36:06 [INFO]-number of epochs that have no update 21
# 2021-01-24 22:36:06 [INFO]-Execute [train_eval_worker] method costing 19128.80 ms

# %% [markdown]
# ### Model Tunning

# %%
from beta_rec.recommenders import SASRec
from beta_rec.datasets.movielens import Movielens_1m,Movielens_100k
from beta_rec.data.sequential_data import SequentialData

dataset = Movielens_100k()
split_dataset = dataset.load_leave_one_out(n_test=1)
data = SequentialData(split_dataset)


config = {"config_file": "./sasrec_default.json",
          "device":"gpu",
          "tune":True
         }
model = SASRec(config)
model.train(data)
