# %% [markdown]
# ## Loading dataset

# %%
from beta_rec.datasets.movielens import Movielens_1m,Movielens_100k
from beta_rec.data.sequential_data import SequentialData

dataset = Movielens_100k()
split_dataset = dataset.load_leave_one_out(n_test=1)
data = SequentialData(split_dataset)
# Out:
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 98114      | 98114      | 98114        | 98114           |
# | nunique | 943        | 1678       | 5            | 48241           |
# +---------+------------+------------+--------------+-----------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95243      | 95243      | 95243        | 95243           |
# | nunique | 943        | 1604       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95243      | 95243      | 95243        | 95243           |
# | nunique | 943        | 1629       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95239      | 95239      | 95239        | 95239           |
# | nunique | 943        | 1625       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95237      | 95237      | 95237        | 95237           |
# | nunique | 943        | 1602       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table

# %% [markdown]
# ### Model config

# %%
config = {"config_file": "../configs/sasrec_default.json",
          "emb_dim":32,
          "num_blocks": 2,
          "num_heads": 2,
          "lr": 0.5,
          "dropout_rate":0.1
         }
# the 'config_file' key is required, that is used load a default config.
# Other keys can be specified to replace the default settings.

# %% [markdown]
# ### Model intialization and training

# %%
from beta_rec.recommenders import SASRec

model = SASRec(config)
model.train(data)
# Out:
# loading config file ../configs/sasrec_default.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +----+--------------------+----------+
# |    | keys               |   values |
# |----+--------------------+----------|
# |  0 | model:emb_dim      |     32   |
# |  1 | model:num_blocks   |      2   |
# |  2 | model:num_heads    |      2   |
# |  3 | model:lr           |      0.5 |
# |  4 | model:dropout_rate |      0.1 |
# +----+--------------------+----------+
# --------------------------------------------------------------------------------
# logs will save in file: /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_173422_bvduqe .stdout.log .stderr.log
# 2021-01-24 17:34:22 [INFO]-
# Python version: 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# [GCC 7.3.0
# 2021-01-24 17:34:22 [INFO]-
# 2021-01-24 17:34:22 [INFO]-pytorch version: 1.7.1
# 2021-01-24 17:34:22 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_173422_bvduqe
# 2021-01-24 17:34:22 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_173422_bvduqe
# 2021-01-24 17:34:22 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/sasrec_result.csv
# 2021-01-24 17:34:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:22 [INFO]-System configs
# 2021-01-24 17:34:22 [INFO]-
# +----+----------------+-------------------------------------------------------------------------------------+
# |    | keys           | values                                                                              |
# |----+----------------+-------------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                   |
# |  1 | log_dir        | logs/                                                                               |
# |  2 | result_dir     | results/                                                                            |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                        |
# |  4 | checkpoint_dir | checkpoints/                                                                        |
# |  5 | dataset_dir    | datasets/                                                                           |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_173422_bvduqe        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                     |
# |  8 | device         | gpu                                                                                 |
# |  9 | seed           | 2020                                                                                |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                              |
# | 11 | k              | [5, 10, 20]                                                                         |
# | 12 | valid_metric   | ndcg                                                                                |
# | 13 | valid_k        | 10                                                                                  |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/sasrec_result.csv                         |
# | 15 | save_mode      | average                                                                             |
# | 16 | model_run_id   | SASRec_default_20210124_173422_bvduqe                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_173422_bvduqe        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_173422_bvduqe |
# +----+----------------+-------------------------------------------------------------------------------------
# 2021-01-24 17:34:22 [INFO]-
# 2021-01-24 17:34:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:22 [INFO]-Get a gpu with the most available memory : 0
# 2021-01-24 17:34:22 [INFO]-[Warning]: port 8003 was already in use.
# 2021-01-24 17:34:22 [INFO]-If you need to use prometheus, please check that port or specify another port number.
# 2021-01-24 17:34:22 [INFO]-Initializing test engine ...
# 2021-01-24 17:34:23 [INFO]-Get a gpu with the most available memory : 0
# 2021-01-24 17:34:23 [INFO]-{'system': {'root_dir': '/home/zm324/workspace/beta-recsys', 'log_dir': 'logs/', 'result_dir': 'results/', 'process_dir': '/home/zm324/workspace/beta-recsys/processes/', 'checkpoint_dir': 'checkpoints/', 'dataset_dir': 'datasets/', 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_173422_bvduqe', 'tune_dir': '/home/zm324/workspace/beta-recsys/tune_results/', 'device': 'gpu', 'seed': 2020, 'metrics': ['ndcg', 'precision', 'recall', 'map'], 'k': [5, 10, 20], 'valid_metric': 'ndcg', 'valid_k': 10, 'result_file': '/home/zm324/workspace/beta-recsys/results/sasrec_result.csv', 'save_mode': 'average', 'model_run_id': 'SASRec_default_20210124_173422_bvduqe', 'log_file': '/home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_173422_bvduqe', 'model_save_dir': '/home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_173422_bvduqe'}, 'dataset': {'dataset': 'ml_100k', 'data_split': 'leave_one_out', 'test_rate': 0.2, 'download': False, 'random': False, 'by_user': False, 'n_test': 10, 'n_negative': 100, 'result_col': ['dataset', 'data_split', 'test_rate', 'n_negative']}, 'model': {'model': 'SASRec', 'config_id': 'default', 'emb_dim': 32, 'num_blocks': 2, 'num_heads': 2, 'maxlen': 200, 'lr': 0.5, 'batch_size': 128, 'batch_eval': True, 'dropout_rate': 0.1, 'optimizer': 'adam', 'l2_emb': 0.1, 'max_epoch': 200, 'max_n_update': 20, 'save_name': 'sasrec.model', 'result_col': ['model', 'emb_dim', 'batch_size', 'maxlen', 'optimizer', 'lr', 'l2_emb'], 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_173422_bvduqe', 'device_str': 'cuda:0', 'n_users': 943, 'n_items': 1678}, 'tunable': [{'name': 'emb_dim', 'type': 'choice', 'values': [32, 64]}, {'name': 'lr', 'type': 'choice', 'values': [1, 0.5, 0.3, 0.1, 0.001]}, {'name': 'lrnum_heads', 'type': 'choice', 'values': [1, 2]}, {'name': 'l2_emb', 'type': 'choice', 'values': [0.0001, 0.001, 0.01, 0.1, 1]}], 'device_str': 'cuda:0'}
# 2021-01-24 17:34:23 [INFO]-Setting device for torch_engine cuda:0
# 2021-01-24 17:34:25 [INFO]-
# SASRec(
#   (item_emb): Embedding(1679, 32, padding_idx=0)
#   (pos_emb): Embedding(200, 32)
#   (emb_dropout): Dropout(p=0.1, inplace=False)
#   (attention_layernorms): ModuleList(
#     (0): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
#     (1): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
#   )
#   (attention_layers): ModuleList(
#     (0): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=32, out_features=32, bias=True)
#     )
#     (1): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=32, out_features=32, bias=True)
#     )
#   )
#   (forward_layernorms): ModuleList(
#     (0): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
#     (1): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
#   )
#   (forward_layers): ModuleList(
#     (0): PointWiseFeedForward(
#       (conv1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#       (conv2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       (dropout2): Dropout(p=0.1, inplace=False)
#     )
#     (1): PointWiseFeedForward(
#       (conv1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#       (conv2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       (dropout2): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (last_layernorm): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
#
# 2021-01-24 17:34:25 [INFO]-
#   0%|          | 0/200 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-01-24 17:34:27 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:27 [INFO]-[Training Epoch 0], Loss 117.65236473083496
#   0%|          | 1/200 [00:05<18:23,  5.54s/it]Epoch 1 starts !
# 2021-01-24 17:34:33 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:38 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 17:34:38 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:38 [INFO]-performance on validation at epoch 0
# 2021-01-24 17:34:38 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0575625 |
# |  1 | precision@10 | 0.0120085 |
# |  2 | recall@10    | 0.120085  |
# |  3 | map@10       | 0.0389635 |
# +----+--------------+-----------
# 2021-01-24 17:34:38 [INFO]-
# 2021-01-24 17:34:38 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:38 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:38 [INFO]-performance on testing at epoch 0
# 2021-01-24 17:34:38 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0509343 |
# |  1 | precision@10 | 0.0112646 |
# |  2 | recall@10    | 0.112646  |
# |  3 | map@10       | 0.032619  |
# +----+--------------+-----------
# 2021-01-24 17:34:38 [INFO]-
# 2021-01-24 17:34:38 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:38 [INFO]-Execute [train_eval_worker] method costing 5070.94 ms
# 2021-01-24 17:34:38 [INFO]-[Training Epoch 1], Loss 67.3749828338623
#   1%|1         | 2/200 [00:15<23:00,  6.97s/it]Epoch 2 starts !
# 2021-01-24 17:34:43 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:48 [INFO]-number of epochs that have no update 1
# 2021-01-24 17:34:48 [INFO]-Execute [train_eval_worker] method costing 4978.65 ms
# 2021-01-24 17:34:48 [INFO]-[Training Epoch 2], Loss 43.23471641540527
#   2%|1         | 3/200 [00:27<27:20,  8.33s/it]Epoch 3 starts !
# 2021-01-24 17:34:54 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:59 [INFO]-Current testEngine.best_valid_performance 0.05756249673047726
# 2021-01-24 17:34:59 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:59 [INFO]-performance on validation at epoch 2
# 2021-01-24 17:34:59 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0598682 |
# |  1 | precision@10 | 0.0123273 |
# |  2 | recall@10    | 0.123273  |
# |  3 | map@10       | 0.0410468 |
# +----+--------------+-----------
# 2021-01-24 17:34:59 [INFO]-
# 2021-01-24 17:34:59 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:59 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:59 [INFO]-performance on testing at epoch 2
# 2021-01-24 17:34:59 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0580562 |
# |  1 | precision@10 | 0.0111583 |
# |  2 | recall@10    | 0.111583  |
# |  3 | map@10       | 0.0420336 |
# +----+--------------+-----------
# 2021-01-24 17:34:59 [INFO]-
# 2021-01-24 17:34:59 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:59 [INFO]-Execute [train_eval_worker] method costing 5018.60 ms
# 2021-01-24 17:35:00 [INFO]-[Training Epoch 3], Loss 31.131142139434814
#   2%|2         | 4/200 [00:37<29:11,  8.94s/it]Epoch 4 starts !
# 2021-01-24 17:35:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:10 [INFO]-Current testEngine.best_valid_performance 0.059868158745213305
# 2021-01-24 17:35:10 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:10 [INFO]-performance on validation at epoch 3
# 2021-01-24 17:35:10 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0609947 |
# |  1 | precision@10 | 0.0126461 |
# |  2 | recall@10    | 0.126461  |
# |  3 | map@10       | 0.0414845 |
# +----+--------------+-----------
# 2021-01-24 17:35:10 [INFO]-
# 2021-01-24 17:35:10 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:10 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:10 [INFO]-performance on testing at epoch 3
# 2021-01-24 17:35:10 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0651351 |
# |  1 | precision@10 | 0.0139214 |
# |  2 | recall@10    | 0.139214  |
# |  3 | map@10       | 0.0432476 |
# +----+--------------+-----------
# 2021-01-24 17:35:10 [INFO]-
# 2021-01-24 17:35:10 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:10 [INFO]-Execute [train_eval_worker] method costing 5221.81 ms
# 2021-01-24 17:35:10 [INFO]-[Training Epoch 4], Loss 23.67091655731201
#   2%|2         | 5/200 [00:50<32:44, 10.08s/it]Epoch 5 starts !
# 2021-01-24 17:35:17 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:22 [INFO]-number of epochs that have no update 1
# 2021-01-24 17:35:22 [INFO]-Execute [train_eval_worker] method costing 5059.40 ms
# 2021-01-24 17:35:23 [INFO]-[Training Epoch 5], Loss 19.65790820121765
#   3%|3         | 6/200 [01:02<34:02, 10.53s/it]Epoch 6 starts !
# 2021-01-24 17:35:29 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:34 [INFO]-number of epochs that have no update 2
# 2021-01-24 17:35:34 [INFO]-Execute [train_eval_worker] method costing 5136.46 ms
# 2021-01-24 17:35:34 [INFO]-[Training Epoch 6], Loss 17.19686269760132
#   4%|3         | 7/200 [01:13<35:00, 10.88s/it]Epoch 7 starts !
# 2021-01-24 17:35:41 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:46 [INFO]-Current testEngine.best_valid_performance 0.06099468422041737
# 2021-01-24 17:35:46 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:46 [INFO]-performance on validation at epoch 6
# 2021-01-24 17:35:46 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0650384 |
# |  1 | precision@10 | 0.014559  |
# |  2 | recall@10    | 0.14559   |
# |  3 | map@10       | 0.0413706 |
# +----+--------------+-----------
# 2021-01-24 17:35:46 [INFO]-
# 2021-01-24 17:35:46 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:46 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:46 [INFO]-performance on testing at epoch 6
# 2021-01-24 17:35:46 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0580661 |
# |  1 | precision@10 | 0.0124336 |
# |  2 | recall@10    | 0.124336  |
# |  3 | map@10       | 0.0385591 |
# +----+--------------+-----------
# 2021-01-24 17:35:46 [INFO]-
# 2021-01-24 17:35:46 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:46 [INFO]-Execute [train_eval_worker] method costing 5189.69 ms
# 2021-01-24 17:35:46 [INFO]-[Training Epoch 7], Loss 16.05021905899048
#   4%|4         | 8/200 [01:24<35:10, 10.99s/it]Epoch 8 starts !
# 2021-01-24 17:35:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:35:57 [INFO]-number of epochs that have no update 1
# 2021-01-24 17:35:57 [INFO]-Execute [train_eval_worker] method costing 5323.32 ms
# 2021-01-24 17:35:57 [INFO]-[Training Epoch 8], Loss 15.159809112548828
#   4%|4         | 9/200 [01:36<35:03, 11.01s/it]Epoch 9 starts !
# 2021-01-24 17:36:03 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:36:08 [INFO]-number of epochs that have no update 2
# 2021-01-24 17:36:08 [INFO]-Execute [train_eval_worker] method costing 5300.75 ms
# 2021-01-24 17:36:09 [INFO]-[Training Epoch 9], Loss 15.092883586883545
#   5%|5         | 10/200 [01:46<34:49, 11.00s/it]Epoch 10 starts !
# 2021-01-24 17:36:14 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:36:19 [INFO]-number of epochs that have no update 3
# 2021-01-24 17:36:19 [INFO]-Execute [train_eval_worker] method costing 5229.30 ms
# 2021-01-24 17:36:19 [INFO]-[Training Epoch 10], Loss 14.421151876449585
#   6%|5         | 11/200 [01:58<34:39, 11.00s/it]Epoch 11 starts !
# 2021-01-24 17:36:25 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:36:30 [INFO]-number of epochs that have no update 4
# 2021-01-24 17:36:30 [INFO]-Execute [train_eval_worker] method costing 5157.76 ms
# 2021-01-24 17:36:30 [INFO]-[Training Epoch 11], Loss 15.557046175003052
#   6%|6         | 12/200 [02:09<35:13, 11.24s/it]Epoch 12 starts !
# 2021-01-24 17:36:37 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:36:42 [INFO]-Current testEngine.best_valid_performance 0.06503838208895774
# 2021-01-24 17:36:42 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:36:42 [INFO]-performance on validation at epoch 11
# 2021-01-24 17:36:42 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0663199 |
# |  1 | precision@10 | 0.0134963 |
# |  2 | recall@10    | 0.134963  |
# |  3 | map@10       | 0.0460697 |
# +----+--------------+-----------
# 2021-01-24 17:36:42 [INFO]-
# 2021-01-24 17:36:42 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:36:42 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:36:42 [INFO]-performance on testing at epoch 11
# 2021-01-24 17:36:42 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0693593 |
# |  1 | precision@10 | 0.014559  |
# |  2 | recall@10    | 0.14559   |
# |  3 | map@10       | 0.0463624 |
# +----+--------------+-----------
# 2021-01-24 17:36:42 [INFO]-
# 2021-01-24 17:36:42 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:36:42 [INFO]-Execute [train_eval_worker] method costing 5412.16 ms
# 2021-01-24 17:36:42 [INFO]-[Training Epoch 12], Loss 14.973333358764648
#   6%|6         | 13/200 [02:21<35:28, 11.38s/it]Epoch 13 starts !
# 2021-01-24 17:36:49 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:36:54 [INFO]-number of epochs that have no update 1
# 2021-01-24 17:36:54 [INFO]-Execute [train_eval_worker] method costing 5343.80 ms
# 2021-01-24 17:36:54 [INFO]-[Training Epoch 13], Loss 14.87325406074524
#   7%|7         | 14/200 [02:33<36:00, 11.61s/it]Epoch 14 starts !
# 2021-01-24 17:37:01 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:37:06 [INFO]-number of epochs that have no update 2
# 2021-01-24 17:37:06 [INFO]-Execute [train_eval_worker] method costing 5333.69 ms
# 2021-01-24 17:37:06 [INFO]-[Training Epoch 14], Loss 14.722183465957642
#   8%|7         | 15/200 [02:44<35:15, 11.43s/it]Epoch 15 starts !
# 2021-01-24 17:37:12 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:37:17 [INFO]-number of epochs that have no update 3
# 2021-01-24 17:37:17 [INFO]-Execute [train_eval_worker] method costing 5417.13 ms
# 2021-01-24 17:37:17 [INFO]-[Training Epoch 15], Loss 14.760259628295898
#   8%|8         | 16/200 [02:55<34:54, 11.38s/it]Epoch 16 starts !
# 2021-01-24 17:37:23 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:37:28 [INFO]-number of epochs that have no update 4
# 2021-01-24 17:37:28 [INFO]-Execute [train_eval_worker] method costing 5227.90 ms
# 2021-01-24 17:37:28 [INFO]-[Training Epoch 16], Loss 14.678049564361572
#   8%|8         | 17/200 [03:07<34:28, 11.30s/it]Epoch 17 starts !
# 2021-01-24 17:37:34 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:37:39 [INFO]-number of epochs that have no update 5
# 2021-01-24 17:37:39 [INFO]-Execute [train_eval_worker] method costing 5295.04 ms
# 2021-01-24 17:37:40 [INFO]-[Training Epoch 17], Loss 14.643895626068115
#   9%|9         | 18/200 [03:19<34:56, 11.52s/it]Epoch 18 starts !
# 2021-01-24 17:37:46 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:37:51 [INFO]-number of epochs that have no update 6
# 2021-01-24 17:37:51 [INFO]-Execute [train_eval_worker] method costing 5277.09 ms
# 2021-01-24 17:37:52 [INFO]-[Training Epoch 18], Loss 15.698272228240967
#  10%|9         | 19/200 [03:31<35:30, 11.77s/it]Epoch 19 starts !
# 2021-01-24 17:37:58 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:38:04 [INFO]-number of epochs that have no update 7
# 2021-01-24 17:38:04 [INFO]-Execute [train_eval_worker] method costing 5192.22 ms
# 2021-01-24 17:38:04 [INFO]-[Training Epoch 19], Loss 15.414606809616089
#  10%|#         | 20/200 [03:43<35:54, 11.97s/it]Epoch 20 starts !
# 2021-01-24 17:38:11 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:38:16 [INFO]-number of epochs that have no update 8
# 2021-01-24 17:38:16 [INFO]-Execute [train_eval_worker] method costing 5357.91 ms
# 2021-01-24 17:38:16 [INFO]-[Training Epoch 20], Loss 14.79200530052185
#  10%|#         | 21/200 [03:55<34:59, 11.73s/it]Epoch 21 starts !
# 2021-01-24 17:38:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:38:27 [INFO]-number of epochs that have no update 9
# 2021-01-24 17:38:27 [INFO]-Execute [train_eval_worker] method costing 5187.12 ms
# 2021-01-24 17:38:27 [INFO]-[Training Epoch 21], Loss 14.512408018112183
#  11%|#1        | 22/200 [04:06<34:14, 11.54s/it]Epoch 22 starts !
# 2021-01-24 17:38:33 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:38:38 [INFO]-number of epochs that have no update 10
# 2021-01-24 17:38:38 [INFO]-Execute [train_eval_worker] method costing 5269.48 ms
# 2021-01-24 17:38:39 [INFO]-[Training Epoch 22], Loss 14.600365161895752
#  12%|#1        | 23/200 [04:17<33:40, 11.41s/it]Epoch 23 starts !
# 2021-01-24 17:38:44 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:38:49 [INFO]-number of epochs that have no update 11
# 2021-01-24 17:38:49 [INFO]-Execute [train_eval_worker] method costing 5185.28 ms
# 2021-01-24 17:38:50 [INFO]-[Training Epoch 23], Loss 14.200212001800537
#  12%|#2        | 24/200 [04:29<34:16, 11.69s/it]Epoch 24 starts !
# 2021-01-24 17:38:57 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:39:02 [INFO]-number of epochs that have no update 12
# 2021-01-24 17:39:02 [INFO]-Execute [train_eval_worker] method costing 5090.31 ms
# 2021-01-24 17:39:02 [INFO]-[Training Epoch 24], Loss 14.231465101242065
#  12%|#2        | 25/200 [04:41<34:05, 11.69s/it]Epoch 25 starts !
# 2021-01-24 17:39:08 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:39:13 [INFO]-number of epochs that have no update 13
# 2021-01-24 17:39:13 [INFO]-Execute [train_eval_worker] method costing 5070.26 ms
# 2021-01-24 17:39:14 [INFO]-[Training Epoch 25], Loss 13.732066750526428
#  13%|#3        | 26/200 [04:53<34:00, 11.73s/it]Epoch 26 starts !
# 2021-01-24 17:39:20 [INFO]---------------------------------------------------------------------------------
#  13%|#3        | 26/200 [04:57<33:13, 11.46s/it]
# 2021-01-24 17:39:25 [INFO]-number of epochs that have no update 14
# 2021-01-24 17:39:25 [INFO]-Execute [train_eval_worker] method costing 5210.04 ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-eb99f7a55386> in <module>
#       2
#       3 model = SASRec(config)
# ----> 4 model.train(data)
#
# ~/anaconda3/envs/beta_rec/lib/python3.6/site-packages/beta_rec/recommenders/sasrec.py in train(self, data)
#     174             train_seq=data.get_train_seq(),
#     175             valid_df=data.valid[0],
# --> 176             test_df=data.test[0],
#     177         )
#     178         self.config["run_time"] = self.monitor.stop()
#
# ~/anaconda3/envs/beta_rec/lib/python3.6/site-packages/beta_rec/core/train_engine.py in _seq_train(self, engine, train_loader, save_dir, train_seq, valid_df, test_df)
#     250             if self.check_early_stop(engine, save_dir, epoch):
#     251                 break
# --> 252             engine.train_an_epoch(train_loader, epoch_id=epoch)
#     253             """evaluate model on validation and test sets"""
#     254             if (valid_df is None) & (test_df is None):
#
# ~/anaconda3/envs/beta_rec/lib/python3.6/site-packages/beta_rec/models/sasrec.py in train_an_epoch(self, sampler, epoch_id)
#     188             u, seq, pos, neg = sampler.next_batch()  # tuples to ndarray
#     189             batch_data = np.array(u), np.array(seq), np.array(pos), np.array(neg)
# --> 190             loss = self.train_single_batch(batch_data)
#     191             # print(
#     192             #     "loss in epoch {} iteration {}: {}".format(epoch, step, loss.item())
#
# ~/anaconda3/envs/beta_rec/lib/python3.6/site-packages/beta_rec/models/sasrec.py in train_single_batch(self, batch_data, ratings)
#     176             loss += self.model.l2_emb * torch.norm(param)
#     177         loss.backward()
# --> 178         self.optimizer.step()
#     179         loss = loss.item()
#     180         return loss
#
# ~/anaconda3/envs/beta_rec/lib/python3.6/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# ~/anaconda3/envs/beta_rec/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps']
#     120                    )
#     121         return loss
#
# ~/anaconda3/envs/beta_rec/lib/python3.6/site-packages/torch/optim/functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      85         # Decay the first and second moment running average coefficient
#      86         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# ---> 87         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#      88         if amsgrad:
#      89             # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %% [markdown]
# ### Model Tunning

# %%
from beta_rec.recommenders import SASRec
from beta_rec.datasets.movielens import Movielens_1m,Movielens_100k
from beta_rec.data.sequential_data import SequentialData

dataset = Movielens_100k()
split_dataset = dataset.load_leave_one_out(n_test=1)
data = SequentialData(split_dataset)


config = {"config_file": "./sasrec_default.json",
          "device":"gpu",
          "tune":True
         }
model = SASRec(config)
model.train(data)
# Out:
# 2021-01-24 17:21:52 [INFO]-(pid=605278)   (pos_emb): Embedding(200, 32)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)   (emb_dropout): Dropout(p=0.1, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)   (attention_layernorms): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     (0): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     (1): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605278)   (attention_layers): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     (0): MultiheadAttention(
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (out_proj): _LinearWithBias(in_features=32, out_features=32, bias=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     (1): MultiheadAttention(
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (out_proj): _LinearWithBias(in_features=32, out_features=32, bias=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605278)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605278)   (forward_layernorms): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     (0): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     (1): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605278)   (forward_layers): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     (0): PointWiseFeedForward(
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (conv1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (dropout1): Dropout(p=0.1, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (relu): ReLU()
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (conv2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (dropout2): Dropout(p=0.1, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     (1): PointWiseFeedForward(
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (conv1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (dropout1): Dropout(p=0.1, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (relu): ReLU()
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (conv2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605278)       (dropout2): Dropout(p=0.1, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605278)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605278)   (last_layernorm): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605278)
# 2021-01-24 17:21:52 [INFO]-(pid=605278) 2021-01-24 17:21:52 [INFO]-
#   0%|          | 0/40 [00:00<?, ?it/s]Epoch 0 starts !021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605279) 2021-01-24 17:21:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:21:52 [INFO]-(pid=605226) loading config file /home/zm324/workspace/beta-recsys/examples/sasrec_default.json
# 2021-01-24 17:21:52 [INFO]-(pid=605226) --------------------------------------------------------------------------------
# 2021-01-24 17:21:52 [INFO]-(pid=605226) Received parameters from command line (or default):
# 2021-01-24 17:21:52 [INFO]-(pid=605226) +----+--------------------+-----------------------------------+
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |    | keys               | values                            |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |----+--------------------+-----------------------------------|
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  0 | system:device      | gpu                               |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  1 | system:root_dir    | /home/zm324/workspace/beta-recsys |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  2 | model:lr           | 0.2                               |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  3 | model:dropout_rate | 0.2                               |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) +----+--------------------+-----------------------------------+
# 2021-01-24 17:21:52 [INFO]-(pid=605226) --------------------------------------------------------------------------------
# 2021-01-24 17:21:52 [INFO]-(pid=605226) logs will save in file: /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_172152_jhaggv .stdout.log .stderr.log
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605226) Python version: 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# 2021-01-24 17:21:52 [INFO]-(pid=605226) [GCC 7.3.0
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-pytorch version: 1.7.1
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_172152_jhaggv
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_172152_jhaggv
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/sasrec_result.csv
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-System configs
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605226) +----+----------------+-------------------------------------------------------------------------------------+
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |    | keys           | values                                                                              |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |----+----------------+-------------------------------------------------------------------------------------|
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                   |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  1 | log_dir        | logs/                                                                               |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  2 | result_dir     | results/                                                                            |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                        |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  4 | checkpoint_dir | checkpoints/                                                                        |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  5 | dataset_dir    | datasets/                                                                           |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_172152_jhaggv        |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                     |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  8 | device         | gpu                                                                                 |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) |  9 | seed           | 2020                                                                                |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                              |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) | 11 | k              | [5, 10, 20]                                                                         |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) | 12 | valid_metric   | ndcg                                                                                |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) | 13 | valid_k        | 10                                                                                  |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/sasrec_result.csv                         |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) | 15 | save_mode      | average                                                                             |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) | 16 | model_run_id   | SASRec_default_20210124_172152_jhaggv                                               |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_172152_jhaggv        |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_172152_jhaggv |
# 2021-01-24 17:21:52 [INFO]-(pid=605226) +----+----------------+-------------------------------------------------------------------------------------
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-[Warning]: port 8003 was already in use.
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-If you need to use prometheus, please check that port or specify another port number.
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-Initializing test engine ...
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-{'system': {'root_dir': '/home/zm324/workspace/beta-recsys', 'log_dir': 'logs/', 'result_dir': 'results/', 'process_dir': '/home/zm324/workspace/beta-recsys/processes/', 'checkpoint_dir': 'checkpoints/', 'dataset_dir': 'datasets/', 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_172152_jhaggv', 'tune_dir': '/home/zm324/workspace/beta-recsys/tune_results/', 'device': 'gpu', 'seed': 2020, 'metrics': ['ndcg', 'precision', 'recall', 'map'], 'k': [5, 10, 20], 'valid_metric': 'ndcg', 'valid_k': 10, 'result_file': '/home/zm324/workspace/beta-recsys/results/sasrec_result.csv', 'save_mode': 'average', 'model_run_id': 'SASRec_default_20210124_172152_jhaggv', 'log_file': '/home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_172152_jhaggv', 'model_save_dir': '/home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_172152_jhaggv'}, 'dataset': {'dataset': 'ml_1m', 'data_split': 'leave_one_out', 'test_rate': 0.2, 'download': False, 'random': False, 'by_user': False, 'n_test': 10, 'n_negative': 100, 'result_col': ['dataset', 'data_split', 'test_rate', 'n_negative']}, 'model': {'model': 'SASRec', 'config_id': 'default', 'emb_dim': 32, 'num_blocks': 2, 'num_heads': 1, 'maxlen': 200, 'lr': 0.2, 'batch_size': 128, 'batch_eval': True, 'dropout_rate': 0.2, 'optimizer': 'adam', 'l2_emb': 0.01, 'max_epoch': 40, 'max_n_update': 7, 'save_name': 'sasrec.model', 'result_col': ['model', 'emb_dim', 'batch_size', 'maxlen', 'optimizer', 'lr', 'l2_emb'], 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_172152_jhaggv', 'device_str': 'cpu', 'n_users': 943, 'n_items': 1678}, 'tunable': [{'name': 'lr', 'type': 'choice', 'values': [1, 0.5, 0.3, 0.2]}, {'name': 'dropout_rate', 'type': 'choice', 'values': [0.1, 0.2, 0.3]}], 'device_str': 'cpu'}
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-Setting device for torch_engine cpu
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605226) SASRec(
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   (item_emb): Embedding(1679, 32, padding_idx=0)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   (pos_emb): Embedding(200, 32)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   (emb_dropout): Dropout(p=0.2, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   (attention_layernorms): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     (0): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     (1): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   (attention_layers): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     (0): MultiheadAttention(
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (out_proj): _LinearWithBias(in_features=32, out_features=32, bias=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     (1): MultiheadAttention(
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (out_proj): _LinearWithBias(in_features=32, out_features=32, bias=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   (forward_layernorms): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     (0): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     (1): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   (forward_layers): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     (0): PointWiseFeedForward(
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (conv1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (dropout1): Dropout(p=0.2, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (relu): ReLU()
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (conv2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (dropout2): Dropout(p=0.2, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     (1): PointWiseFeedForward(
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (conv1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (dropout1): Dropout(p=0.2, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (relu): ReLU()
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (conv2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605226)       (dropout2): Dropout(p=0.2, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605226)   (last_layernorm): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605226)
# 2021-01-24 17:21:52 [INFO]-(pid=605226) 2021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605275) loading config file /home/zm324/workspace/beta-recsys/examples/sasrec_default.json
# 2021-01-24 17:21:52 [INFO]-(pid=605275) --------------------------------------------------------------------------------
# 2021-01-24 17:21:52 [INFO]-(pid=605275) Received parameters from command line (or default):
# 2021-01-24 17:21:52 [INFO]-(pid=605275) +----+--------------------+-----------------------------------+
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |    | keys               | values                            |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |----+--------------------+-----------------------------------|
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  0 | system:device      | gpu                               |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  1 | system:root_dir    | /home/zm324/workspace/beta-recsys |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  2 | model:lr           | 0.2                               |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  3 | model:dropout_rate | 0.3                               |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) +----+--------------------+-----------------------------------+
# 2021-01-24 17:21:52 [INFO]-(pid=605275) --------------------------------------------------------------------------------
# 2021-01-24 17:21:52 [INFO]-(pid=605275) logs will save in file: /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_172152_mvaydp .stdout.log .stderr.log
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605275) Python version: 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# 2021-01-24 17:21:52 [INFO]-(pid=605275) [GCC 7.3.0
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-pytorch version: 1.7.1
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_172152_mvaydp
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_172152_mvaydp
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/sasrec_result.csv
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-System configs
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605275) +----+----------------+-------------------------------------------------------------------------------------+
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |    | keys           | values                                                                              |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |----+----------------+-------------------------------------------------------------------------------------|
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                   |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  1 | log_dir        | logs/                                                                               |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  2 | result_dir     | results/                                                                            |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                        |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  4 | checkpoint_dir | checkpoints/                                                                        |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  5 | dataset_dir    | datasets/                                                                           |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_172152_mvaydp        |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                     |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  8 | device         | gpu                                                                                 |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) |  9 | seed           | 2020                                                                                |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                              |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) | 11 | k              | [5, 10, 20]                                                                         |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) | 12 | valid_metric   | ndcg                                                                                |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) | 13 | valid_k        | 10                                                                                  |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/sasrec_result.csv                         |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) | 15 | save_mode      | average                                                                             |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) | 16 | model_run_id   | SASRec_default_20210124_172152_mvaydp                                               |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_172152_mvaydp        |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_172152_mvaydp |
# 2021-01-24 17:21:52 [INFO]-(pid=605275) +----+----------------+-------------------------------------------------------------------------------------
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-[Warning]: port 8003 was already in use.
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-If you need to use prometheus, please check that port or specify another port number.
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-Initializing test engine ...
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-{'system': {'root_dir': '/home/zm324/workspace/beta-recsys', 'log_dir': 'logs/', 'result_dir': 'results/', 'process_dir': '/home/zm324/workspace/beta-recsys/processes/', 'checkpoint_dir': 'checkpoints/', 'dataset_dir': 'datasets/', 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_172152_mvaydp', 'tune_dir': '/home/zm324/workspace/beta-recsys/tune_results/', 'device': 'gpu', 'seed': 2020, 'metrics': ['ndcg', 'precision', 'recall', 'map'], 'k': [5, 10, 20], 'valid_metric': 'ndcg', 'valid_k': 10, 'result_file': '/home/zm324/workspace/beta-recsys/results/sasrec_result.csv', 'save_mode': 'average', 'model_run_id': 'SASRec_default_20210124_172152_mvaydp', 'log_file': '/home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_172152_mvaydp', 'model_save_dir': '/home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_172152_mvaydp'}, 'dataset': {'dataset': 'ml_1m', 'data_split': 'leave_one_out', 'test_rate': 0.2, 'download': False, 'random': False, 'by_user': False, 'n_test': 10, 'n_negative': 100, 'result_col': ['dataset', 'data_split', 'test_rate', 'n_negative']}, 'model': {'model': 'SASRec', 'config_id': 'default', 'emb_dim': 32, 'num_blocks': 2, 'num_heads': 1, 'maxlen': 200, 'lr': 0.2, 'batch_size': 128, 'batch_eval': True, 'dropout_rate': 0.3, 'optimizer': 'adam', 'l2_emb': 0.01, 'max_epoch': 40, 'max_n_update': 7, 'save_name': 'sasrec.model', 'result_col': ['model', 'emb_dim', 'batch_size', 'maxlen', 'optimizer', 'lr', 'l2_emb'], 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_172152_mvaydp', 'device_str': 'cpu', 'n_users': 943, 'n_items': 1678}, 'tunable': [{'name': 'lr', 'type': 'choice', 'values': [1, 0.5, 0.3, 0.2]}, {'name': 'dropout_rate', 'type': 'choice', 'values': [0.1, 0.2, 0.3]}], 'device_str': 'cpu'}
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-Setting device for torch_engine cpu
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-
# 2021-01-24 17:21:52 [INFO]-(pid=605275) SASRec(
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   (item_emb): Embedding(1679, 32, padding_idx=0)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   (pos_emb): Embedding(200, 32)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   (emb_dropout): Dropout(p=0.3, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   (attention_layernorms): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     (0): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     (1): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   (attention_layers): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     (0): MultiheadAttention(
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (out_proj): _LinearWithBias(in_features=32, out_features=32, bias=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     (1): MultiheadAttention(
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (out_proj): _LinearWithBias(in_features=32, out_features=32, bias=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   (forward_layernorms): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     (0): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     (1): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   (forward_layers): ModuleList(
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     (0): PointWiseFeedForward(
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (conv1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (dropout1): Dropout(p=0.3, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (relu): ReLU()
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (conv2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (dropout2): Dropout(p=0.3, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     (1): PointWiseFeedForward(
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (conv1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (dropout1): Dropout(p=0.3, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (relu): ReLU()
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (conv2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
# 2021-01-24 17:21:52 [INFO]-(pid=605275)       (dropout2): Dropout(p=0.3, inplace=False)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)     )
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   )
# 2021-01-24 17:21:52 [INFO]-(pid=605275)   (last_layernorm): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
# 2021-01-24 17:21:52 [INFO]-(pid=605275)
# 2021-01-24 17:21:52 [INFO]-(pid=605275) 2021-01-24 17:21:52 [INFO]-
#   0%|          | 0/40 [00:00<?, ?it/s]Epoch 0 starts !021-01-24 17:21:53 [INFO]-
# 2021-01-24 17:21:53 [INFO]-(pid=605277) 2021-01-24 17:21:53 [INFO]---------------------------------------------------------------------------------
#   0%|          | 0/40 [00:00<?, ?it/s]Epoch 0 starts !021-01-24 17:21:53 [INFO]-
# 2021-01-24 17:21:53 [INFO]-(pid=605220) 2021-01-24 17:21:53 [INFO]---------------------------------------------------------------------------------
#   0%|          | 0/40 [00:00<?, ?it/s]Epoch 0 starts !021-01-24 17:21:53 [INFO]-
# 2021-01-24 17:21:53 [INFO]-(pid=605274) 2021-01-24 17:21:53 [INFO]---------------------------------------------------------------------------------
#   0%|          | 0/40 [00:00<?, ?it/s]Epoch 0 starts !021-01-24 17:21:53 [INFO]-
# 2021-01-24 17:21:53 [INFO]-(pid=605226) 2021-01-24 17:21:53 [INFO]---------------------------------------------------------------------------------
#   0%|          | 0/40 [00:00<?, ?it/s]Epoch 0 starts !021-01-24 17:21:54 [INFO]-
# 2021-01-24 17:21:54 [INFO]-(pid=605278) 2021-01-24 17:21:54 [INFO]---------------------------------------------------------------------------------
#   0%|          | 0/40 [00:00<?, ?it/s]Epoch 0 starts !021-01-24 17:21:54 [INFO]-
# 2021-01-24 17:21:54 [INFO]-(pid=605275) 2021-01-24 17:21:54 [INFO]---------------------------------------------------------------------------------
#   0%|          | 0/40 [00:00<?, ?it/s]Epoch 0 starts !021-01-24 17:21:54 [INFO]-
# 2021-01-24 17:21:54 [INFO]-(pid=605272) 2021-01-24 17:21:54 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:21:59 [INFO]-(pid=605273) 2021-01-24 17:21:59 [INFO]-[Training Epoch 0], Loss 82.28719425201416
# 2021-01-24 17:22:00 [INFO]-(pid=605276) 2021-01-24 17:22:00 [INFO]-[Training Epoch 0], Loss 33.646209955215454
# 2021-01-24 17:22:01 [INFO]-(pid=605225) 2021-01-24 17:22:01 [INFO]-[Training Epoch 0], Loss 84.31131744384766
# 2021-01-24 17:22:01 [INFO]-(pid=605280) 2021-01-24 17:22:01 [INFO]-[Training Epoch 0], Loss 82.87965297698975
# 2021-01-24 17:22:02 [INFO]-(pid=605279) 2021-01-24 17:22:02 [INFO]-[Training Epoch 0], Loss 34.893964767456055
# 2021-01-24 17:22:03 [INFO]-(pid=605277) 2021-01-24 17:22:03 [INFO]-[Training Epoch 0], Loss 30.92950201034546
# 2021-01-24 17:22:03 [INFO]-(pid=605220) 2021-01-24 17:22:03 [INFO]-[Training Epoch 0], Loss 33.8961443901062
# 2021-01-24 17:22:03 [INFO]-(pid=605274) 2021-01-24 17:22:03 [INFO]-[Training Epoch 0], Loss 30.835042715072632
# 2021-01-24 17:22:03 [INFO]-(pid=605226) 2021-01-24 17:22:03 [INFO]-[Training Epoch 0], Loss 31.121386289596558
# 2021-01-24 17:22:04 [INFO]-(pid=605278) 2021-01-24 17:22:04 [INFO]-[Training Epoch 0], Loss 30.899747371673584
# 2021-01-24 17:22:04 [INFO]-(pid=605272) 2021-01-24 17:22:04 [INFO]-[Training Epoch 0], Loss 31.13222908973694
# 2021-01-24 17:22:04 [INFO]-(pid=605275) 2021-01-24 17:22:04 [INFO]-[Training Epoch 0], Loss 31.377649545669556
#   2%|2         | 1/40 [00:19<12:59, 19.98s/it]Epoch 1 starts !4 17:22:10 [INFO]-
# 2021-01-24 17:22:10 [INFO]-(pid=605273) 2021-01-24 17:22:10 [INFO]---------------------------------------------------------------------------------
#   2%|2         | 1/40 [00:19<12:50, 19.75s/it]Epoch 1 starts !4 17:22:11 [INFO]-
# 2021-01-24 17:22:11 [INFO]-(pid=605276) 2021-01-24 17:22:11 [INFO]---------------------------------------------------------------------------------
#   2%|2         | 1/40 [00:20<13:13, 20.34s/it]Epoch 1 starts !4 17:22:11 [INFO]-
# 2021-01-24 17:22:11 [INFO]-(pid=605225) 2021-01-24 17:22:11 [INFO]---------------------------------------------------------------------------------
#   2%|2         | 1/40 [00:19<12:47, 19.69s/it]Epoch 1 starts !4 17:22:11 [INFO]-
# 2021-01-24 17:22:11 [INFO]-(pid=605280) 2021-01-24 17:22:11 [INFO]---------------------------------------------------------------------------------
#   2%|2         | 1/40 [00:20<13:11, 20.29s/it]Epoch 1 starts !4 17:22:12 [INFO]-
# 2021-01-24 17:22:12 [INFO]-(pid=605279) 2021-01-24 17:22:12 [INFO]---------------------------------------------------------------------------------
#   2%|2         | 1/40 [00:19<12:51, 19.79s/it]Epoch 1 starts !4 17:22:13 [INFO]-
# 2021-01-24 17:22:13 [INFO]-(pid=605277) 2021-01-24 17:22:13 [INFO]---------------------------------------------------------------------------------
#   2%|2         | 1/40 [00:20<13:16, 20.41s/it]Epoch 1 starts !4 17:22:13 [INFO]-
# 2021-01-24 17:22:13 [INFO]-(pid=605220) 2021-01-24 17:22:13 [INFO]---------------------------------------------------------------------------------
#   2%|2         | 1/40 [00:20<13:13, 20.36s/it]Epoch 1 starts !4 17:22:13 [INFO]-
# 2021-01-24 17:22:13 [INFO]-(pid=605274) 2021-01-24 17:22:13 [INFO]---------------------------------------------------------------------------------
#   2%|2         | 1/40 [00:20<13:17, 20.45s/it]Epoch 1 starts !4 17:22:13 [INFO]-
# 2021-01-24 17:22:14 [INFO]-(pid=605226) 2021-01-24 17:22:13 [INFO]---------------------------------------------------------------------------------
#   2%|2         | 1/40 [00:20<13:26, 20.67s/it]Epoch 1 starts !4 17:22:14 [INFO]-
# 2021-01-24 17:22:14 [INFO]-(pid=605278) 2021-01-24 17:22:14 [INFO]---------------------------------------------------------------------------------
#   2%|2         | 1/40 [00:20<13:02, 20.06s/it]Epoch 1 starts !4 17:22:14 [INFO]-
# 2021-01-24 17:22:15 [INFO]-(pid=605272) 2021-01-24 17:22:14 [INFO]---------------------------------------------------------------------------------
#   2%|2         | 1/40 [00:20<13:23, 20.61s/it]Epoch 1 starts !4 17:22:15 [INFO]-
# 2021-01-24 17:22:15 [INFO]-(pid=605275) 2021-01-24 17:22:15 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]-performance on validation at epoch 0
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]-
# 2021-01-24 17:22:19 [INFO]-(pid=605273) +----+--------------+-----------+
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |    | metrics      |    values |
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |----+--------------+-----------|
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |  0 | ndcg@10      | 0.048468  |
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |  1 | precision@10 | 0.0110521 |
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |  2 | recall@10    | 0.110521  |
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |  3 | map@10       | 0.0300031 |
# 2021-01-24 17:22:19 [INFO]-(pid=605273) +----+--------------+-----------
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]-
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]-performance on testing at epoch 0
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]-
# 2021-01-24 17:22:19 [INFO]-(pid=605273) +----+--------------+-----------+
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |    | metrics      |    values |
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |----+--------------+-----------|
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |  0 | ndcg@10      | 0.0454304 |
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |  1 | precision@10 | 0.0098831 |
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |  2 | recall@10    | 0.098831  |
# 2021-01-24 17:22:19 [INFO]-(pid=605273) |  3 | map@10       | 0.0296063 |
# 2021-01-24 17:22:19 [INFO]-(pid=605273) +----+--------------+-----------
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]-
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:19 [INFO]-(pid=605273) 2021-01-24 17:22:19 [INFO]-Execute [train_eval_worker] method costing 8415.17 ms
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]-performance on validation at epoch 0
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]-
# 2021-01-24 17:22:20 [INFO]-(pid=605225) +----+--------------+-----------+
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |    | metrics      |    values |
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |----+--------------+-----------|
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |  0 | ndcg@10      | 0.0585181 |
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |  1 | precision@10 | 0.0127524 |
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |  2 | recall@10    | 0.127524  |
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |  3 | map@10       | 0.0381404 |
# 2021-01-24 17:22:20 [INFO]-(pid=605225) +----+--------------+-----------
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]-
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]-performance on testing at epoch 0
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]-
# 2021-01-24 17:22:20 [INFO]-(pid=605225) +----+--------------+-----------+
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |    | metrics      |    values |
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |----+--------------+-----------|
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |  0 | ndcg@10      | 0.0573208 |
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |  1 | precision@10 | 0.0129649 |
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |  2 | recall@10    | 0.129649  |
# 2021-01-24 17:22:20 [INFO]-(pid=605225) |  3 | map@10       | 0.0361626 |
# 2021-01-24 17:22:20 [INFO]-(pid=605225) +----+--------------+-----------
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]-
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:20 [INFO]-(pid=605225) 2021-01-24 17:22:20 [INFO]-Execute [train_eval_worker] method costing 8487.23 ms
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]-performance on validation at epoch 0
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]-
# 2021-01-24 17:22:20 [INFO]-(pid=605276) +----+--------------+------------+
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |    | metrics      |     values |
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |----+--------------+------------|
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |  0 | ndcg@10      | 0.0405514  |
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |  1 | precision@10 | 0.00913921 |
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |  2 | recall@10    | 0.0913921  |
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |  3 | map@10       | 0.0256735  |
# 2021-01-24 17:22:20 [INFO]-(pid=605276) +----+--------------+------------
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]-
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]-performance on testing at epoch 0
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]-
# 2021-01-24 17:22:20 [INFO]-(pid=605276) +----+--------------+------------+
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |    | metrics      |     values |
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |----+--------------+------------|
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |  0 | ndcg@10      | 0.0398567  |
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |  1 | precision@10 | 0.00967056 |
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |  2 | recall@10    | 0.0967056  |
# 2021-01-24 17:22:20 [INFO]-(pid=605276) |  3 | map@10       | 0.0234329  |
# 2021-01-24 17:22:20 [INFO]-(pid=605276) +----+--------------+------------
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]-
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:20 [INFO]-(pid=605276) 2021-01-24 17:22:20 [INFO]-Execute [train_eval_worker] method costing 9138.24 ms
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]-performance on validation at epoch 0
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]-
# 2021-01-24 17:22:21 [INFO]-(pid=605280) +----+--------------+-----------+
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |    | metrics      |    values |
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |----+--------------+-----------|
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |  0 | ndcg@10      | 0.0556383 |
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |  1 | precision@10 | 0.012221  |
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |  2 | recall@10    | 0.12221   |
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |  3 | map@10       | 0.0357746 |
# 2021-01-24 17:22:21 [INFO]-(pid=605280) +----+--------------+-----------
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]-
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]-performance on testing at epoch 0
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]-
# 2021-01-24 17:22:21 [INFO]-(pid=605280) +----+--------------+-----------+
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |    | metrics      |    values |
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |----+--------------+-----------|
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |  0 | ndcg@10      | 0.0630505 |
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |  1 | precision@10 | 0.0138151 |
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |  2 | recall@10    | 0.138151  |
# 2021-01-24 17:22:21 [INFO]-(pid=605280) |  3 | map@10       | 0.0405972 |
# 2021-01-24 17:22:21 [INFO]-(pid=605280) +----+--------------+-----------
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]-
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:21 [INFO]-(pid=605280) 2021-01-24 17:22:21 [INFO]-Execute [train_eval_worker] method costing 9890.32 ms
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]-performance on validation at epoch 0
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]-
# 2021-01-24 17:22:22 [INFO]-(pid=605220) +----+--------------+-----------+
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |    | metrics      |    values |
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |----+--------------+-----------|
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |  0 | ndcg@10      | 0.0522641 |
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |  1 | precision@10 | 0.011796  |
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |  2 | recall@10    | 0.11796   |
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |  3 | map@10       | 0.0327585 |
# 2021-01-24 17:22:22 [INFO]-(pid=605220) +----+--------------+-----------
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]-
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]-performance on testing at epoch 0
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]-
# 2021-01-24 17:22:22 [INFO]-(pid=605220) +----+--------------+-----------+
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |    | metrics      |    values |
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |----+--------------+-----------|
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |  0 | ndcg@10      | 0.0633337 |
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |  1 | precision@10 | 0.0139214 |
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |  2 | recall@10    | 0.139214  |
# 2021-01-24 17:22:22 [INFO]-(pid=605220) |  3 | map@10       | 0.0407651 |
# 2021-01-24 17:22:22 [INFO]-(pid=605220) +----+--------------+-----------
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]-
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:22 [INFO]-(pid=605220) 2021-01-24 17:22:22 [INFO]-Execute [train_eval_worker] method costing 8636.45 ms
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]-performance on validation at epoch 0
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]-
# 2021-01-24 17:22:22 [INFO]-(pid=605279) +----+--------------+-----------+
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |    | metrics      |    values |
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |----+--------------+-----------|
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |  0 | ndcg@10      | 0.0562165 |
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |  1 | precision@10 | 0.0123273 |
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |  2 | recall@10    | 0.123273  |
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |  3 | map@10       | 0.0362701 |
# 2021-01-24 17:22:22 [INFO]-(pid=605279) +----+--------------+-----------
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]-
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]-performance on testing at epoch 0
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]-
# 2021-01-24 17:22:22 [INFO]-(pid=605279) +----+--------------+-----------+
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |    | metrics      |    values |
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |----+--------------+-----------|
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |  0 | ndcg@10      | 0.0585538 |
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |  1 | precision@10 | 0.0127524 |
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |  2 | recall@10    | 0.127524  |
# 2021-01-24 17:22:22 [INFO]-(pid=605279) |  3 | map@10       | 0.0378966 |
# 2021-01-24 17:22:22 [INFO]-(pid=605279) +----+--------------+-----------
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]-
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:22 [INFO]-(pid=605279) 2021-01-24 17:22:22 [INFO]-Execute [train_eval_worker] method costing 9890.11 ms
# 2021-01-24 17:22:22 [INFO]-(pid=605226) 2021-01-24 17:22:22 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 17:22:22 [INFO]-(pid=605226) 2021-01-24 17:22:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:22:22 [INFO]-(pid=605226) 2021-01-24 17:22:22 [INFO]-performance on validation at epoch 0
# 2021-01-24 17:22:22 [INFO]-(pid=605226) 2021-01-24 17:22:22 [INFO]-
# 2021-01-24 17:22:22 [INFO]-(pid=605226) +----+--------------+-----------+
# 2021-01-24 17:22:22 [INFO]-(pid=605226) |    | metrics      |    values |
# 2021-01-24 17:22:22 [INFO]-(pid=605226) |----+--------------+-----------|
# 2021-01-24 17:22:22 [INFO]-(pid=605226) |  0 | ndcg@10      | 0.0554398 |
# 2021-01-24 17:22:22 [INFO]-(pid=605226) |  1 | precision@10 | 0.012221  |
# ...
# 2021-01-24 17:31:21 [INFO]-
# {'valid_metric': 0.07171192968214114,
#  'model_save_dir': '/home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_172150_jqvkfd/sasrec.model'}
# 2021-01-24 17:32:06 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:32:06 [INFO]-Loaded training set statistics
# 2021-01-24 17:32:06 [INFO]-
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 98114      | 98114      | 98114        | 98114           |
# | nunique | 943        | 1678       | 5            | 48241           |
# +---------+------------+------------+--------------+-----------------
# 2021-01-24 17:32:06 [INFO]-
# 2021-01-24 17:32:06 [INFO]-valid_data_0 statistics
# 2021-01-24 17:32:06 [INFO]-
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95243      | 95243      | 95243        | 95243           |
# | nunique | 943        | 1604       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------
# 2021-01-24 17:32:06 [INFO]-
# 2021-01-24 17:32:06 [INFO]-test_data_0 statistics
# 2021-01-24 17:32:06 [INFO]-
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95243      | 95243      | 95243        | 95243           |
# | nunique | 943        | 1629       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------
# 2021-01-24 17:32:06 [INFO]-
# 2021-01-24 17:32:06 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:32:06 [INFO]-After intersection, testing set [0] statistics
# 2021-01-24 17:32:06 [INFO]-
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95239      | 95239      | 95239        | 95239           |
# | nunique | 943        | 1625       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------
# 2021-01-24 17:32:06 [INFO]-
# 2021-01-24 17:32:06 [INFO]-After intersection, validation set [0] statistics
# 2021-01-24 17:32:06 [INFO]-
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95237      | 95237      | 95237        | 95237           |
# | nunique | 943        | 1602       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------
# 2021-01-24 17:32:06 [INFO]-
# 2021-01-24 17:32:07 [INFO]-Filling alias table
# 2021-01-24 17:32:07 [INFO]-Filling alias table
# 2021-01-24 17:33:34 [INFO]-loading config file ../configs/sasrec_default.json
# 2021-01-24 17:33:34 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:33:34 [INFO]-Received parameters from command line (or default):
# 2021-01-24 17:33:34 [INFO]-
# +----+--------------------+----------+
# |    | keys               |   values |
# |----+--------------------+----------|
# |  0 | model:emb_dim      |     32   |
# |  1 | model:num_blocks   |      2   |
# |  2 | model:num_heads    |      2   |
# |  3 | model:lr           |      0.5 |
# |  4 | model:dropout_rate |      0.1 |
# +----+--------------------+----------
# 2021-01-24 17:33:34 [INFO]-
# 2021-01-24 17:33:34 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:33:34 [INFO]-logs will save in file: /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_173334_tsxhwv .stdout.log .stderr.log
# 2021-01-24 17:33:34 [INFO]-
# 2021-01-24 17:33:34 [INFO]-
# Python version: 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# [GCC 7.3.0
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]-
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]-pytorch version: 1.7.1
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_173334_tsxhwv
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_173334_tsxhwv
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/sasrec_result.csv
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]-System configs
# 2021-01-24 17:33:34 [INFO]-
# 2021-01-24 17:33:34 [INFO]-
# +----+----------------+-------------------------------------------------------------------------------------+
# |    | keys           | values                                                                              |
# |----+----------------+-------------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                   |
# |  1 | log_dir        | logs/                                                                               |
# |  2 | result_dir     | results/                                                                            |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                        |
# |  4 | checkpoint_dir | checkpoints/                                                                        |
# |  5 | dataset_dir    | datasets/                                                                           |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_173334_tsxhwv        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                     |
# |  8 | device         | gpu                                                                                 |
# |  9 | seed           | 2020                                                                                |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                              |
# | 11 | k              | [5, 10, 20]                                                                         |
# | 12 | valid_metric   | ndcg                                                                                |
# | 13 | valid_k        | 10                                                                                  |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/sasrec_result.csv                         |
# | 15 | save_mode      | average                                                                             |
# | 16 | model_run_id   | SASRec_default_20210124_173334_tsxhwv                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_173334_tsxhwv        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_173334_tsxhwv |
# +----+----------------+-------------------------------------------------------------------------------------
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]-
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]-Get a gpu with the most available memory : 0
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]-[Warning]: port 8003 was already in use.
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]-If you need to use prometheus, please check that port or specify another port number.
# 2021-01-24 17:33:34 [INFO]-2021-01-24 17:33:34 [INFO]-Initializing test engine ...
# 2021-01-24 17:33:35 [INFO]-2021-01-24 17:33:35 [INFO]-Get a gpu with the most available memory : 0
# 2021-01-24 17:33:35 [INFO]-2021-01-24 17:33:35 [INFO]-{'system': {'root_dir': '/home/zm324/workspace/beta-recsys', 'log_dir': 'logs/', 'result_dir': 'results/', 'process_dir': '/home/zm324/workspace/beta-recsys/processes/', 'checkpoint_dir': 'checkpoints/', 'dataset_dir': 'datasets/', 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_173334_tsxhwv', 'tune_dir': '/home/zm324/workspace/beta-recsys/tune_results/', 'device': 'gpu', 'seed': 2020, 'metrics': ['ndcg', 'precision', 'recall', 'map'], 'k': [5, 10, 20], 'valid_metric': 'ndcg', 'valid_k': 10, 'result_file': '/home/zm324/workspace/beta-recsys/results/sasrec_result.csv', 'save_mode': 'average', 'model_run_id': 'SASRec_default_20210124_173334_tsxhwv', 'log_file': '/home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_173334_tsxhwv', 'model_save_dir': '/home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_173334_tsxhwv'}, 'dataset': {'dataset': 'ml_100k', 'data_split': 'leave_one_out', 'test_rate': 0.2, 'download': False, 'random': False, 'by_user': False, 'n_test': 10, 'n_negative': 100, 'result_col': ['dataset', 'data_split', 'test_rate', 'n_negative']}, 'model': {'model': 'SASRec', 'config_id': 'default', 'emb_dim': 32, 'num_blocks': 2, 'num_heads': 2, 'maxlen': 200, 'lr': 0.5, 'batch_size': 128, 'batch_eval': True, 'dropout_rate': 0.1, 'optimizer': 'adam', 'l2_emb': 0.1, 'max_epoch': 200, 'max_n_update': 20, 'save_name': 'sasrec.model', 'result_col': ['model', 'emb_dim', 'batch_size', 'maxlen', 'optimizer', 'lr', 'l2_emb'], 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_173334_tsxhwv', 'device_str': 'cuda:0', 'n_users': 943, 'n_items': 1678}, 'tunable': [{'name': 'emb_dim', 'type': 'choice', 'values': [32, 64]}, {'name': 'lr', 'type': 'choice', 'values': [1, 0.5, 0.3, 0.1, 0.001]}, {'name': 'lrnum_heads', 'type': 'choice', 'values': [1, 2]}, {'name': 'l2_emb', 'type': 'choice', 'values': [0.0001, 0.001, 0.01, 0.1, 1]}], 'device_str': 'cuda:0'}
# 2021-01-24 17:33:35 [INFO]-2021-01-24 17:33:35 [INFO]-Setting device for torch_engine cuda:0
# 2021-01-24 17:33:38 [INFO]-
# 2021-01-24 17:33:38 [INFO]-
# SASRec(
#   (item_emb): Embedding(1679, 32, padding_idx=0)
#   (pos_emb): Embedding(200, 32)
#   (emb_dropout): Dropout(p=0.1, inplace=False)
#   (attention_layernorms): ModuleList(
#     (0): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
#     (1): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
#   )
#   (attention_layers): ModuleList(
#     (0): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=32, out_features=32, bias=True)
#     )
#     (1): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=32, out_features=32, bias=True)
#     )
#   )
#   (forward_layernorms): ModuleList(
#     (0): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
#     (1): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
#   )
#   (forward_layers): ModuleList(
#     (0): PointWiseFeedForward(
#       (conv1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#       (conv2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       (dropout2): Dropout(p=0.1, inplace=False)
#     )
#     (1): PointWiseFeedForward(
#       (conv1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#       (conv2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       (dropout2): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (last_layernorm): LayerNorm((32,), eps=1e-08, elementwise_affine=True)
#
# 2021-01-24 17:33:38 [INFO]-2021-01-24 17:33:38 [INFO]-
#   0%|          | 0/200 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-01-24 17:33:40 [INFO]-2021-01-24 17:33:40 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:33:40 [INFO]-2021-01-24 17:33:40 [INFO]-[Training Epoch 0], Loss 117.83878421783447
#   0%|          | 1/200 [00:07<24:23,  7.35s/it]Epoch 1 starts !
# 2021-01-24 17:33:47 [INFO]-2021-01-24 17:33:47 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:33:53 [INFO]-2021-01-24 17:33:53 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 17:33:53 [INFO]-2021-01-24 17:33:53 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:33:53 [INFO]-2021-01-24 17:33:53 [INFO]-performance on validation at epoch 0
# 2021-01-24 17:33:53 [INFO]-
# 2021-01-24 17:33:53 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0590446 |
# |  1 | precision@10 | 0.0121148 |
# |  2 | recall@10    | 0.121148  |
# |  3 | map@10       | 0.0407364 |
# +----+--------------+-----------
# 2021-01-24 17:33:53 [INFO]-2021-01-24 17:33:53 [INFO]-
# 2021-01-24 17:33:53 [INFO]-2021-01-24 17:33:53 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:33:53 [INFO]-2021-01-24 17:33:53 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:33:53 [INFO]-2021-01-24 17:33:53 [INFO]-performance on testing at epoch 0
# 2021-01-24 17:33:53 [INFO]-
# 2021-01-24 17:33:53 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0516997 |
# |  1 | precision@10 | 0.0114772 |
# |  2 | recall@10    | 0.114772  |
# |  3 | map@10       | 0.0329542 |
# +----+--------------+-----------
# 2021-01-24 17:33:53 [INFO]-2021-01-24 17:33:53 [INFO]-
# 2021-01-24 17:33:53 [INFO]-2021-01-24 17:33:53 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:33:53 [INFO]-2021-01-24 17:33:53 [INFO]-Execute [train_eval_worker] method costing 5836.97 ms
# 2021-01-24 17:33:53 [INFO]-2021-01-24 17:33:53 [INFO]-[Training Epoch 1], Loss 68.49924755096436
#   1%|1         | 2/200 [00:20<29:50,  9.04s/it]Epoch 2 starts !
# 2021-01-24 17:34:00 [INFO]-2021-01-24 17:34:00 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 17:34:06 [INFO]-2021-01-24 17:34:06 [INFO]-number of epochs that have no update 1
# 2021-01-24 17:34:06 [INFO]-2021-01-24 17:34:06 [INFO]-Execute [train_eval_worker] method costing 5654.28 ms
# 2021-01-24 17:34:06 [INFO]-2021-01-24 17:34:06 [INFO]-[Training Epoch 2], Loss 44.07005500793457
#   1%|1         | 2/200 [00:31<52:26, 15.89s/it][INFO]-
# 2021-01-24 17:34:12 [ERROR]-
# 2021-01-24 17:34:12 [ERROR]-
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "/home/zm324/anaconda3/envs/beta_rec/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/beta_rec/utils/monitor.py", line 116, in run
#     self.write_gpu_status()
#   File "/home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/beta_rec/utils/monitor.py", line 93, in write_gpu_status
#     self.GPU = GPUtil.getGPUs()[self.gpu_id]
# IndexError: list index out of range
# 2021-01-24 17:34:12 [ERROR]-2021-01-24 17:34:12 [ERROR]-
