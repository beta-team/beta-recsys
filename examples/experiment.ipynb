# %%
import sys

sys.path.append("../")

# %% [markdown]
# ## Loading dataset

# %%
from beta_rec.datasets.movielens import Movielens_100k

from beta_rec.data.base_data import BaseData

# Initialise dataset and the corresponding data split strategy

dataset = Movielens_100k()
split_dataset = dataset.load_leave_one_out(n_test=1)
data = BaseData(split_dataset)
# Out:
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 98114      | 98114      | 98114        | 98114           |
# | nunique | 943        | 1678       | 5            | 48241           |
# +---------+------------+------------+--------------+-----------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95243      | 95243      | 95243        | 95243           |
# | nunique | 943        | 1625       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95243      | 95243      | 95243        | 95243           |
# | nunique | 943        | 1621       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95238      | 95238      | 95238        | 95238           |
# | nunique | 943        | 1618       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 95240      | 95240      | 95240        | 95240           |
# | nunique | 943        | 1623       | 6            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table

# %% [markdown]
# # Initialise and experiment models on the dataset

# %%
from beta_rec.experiment.experiment import Experiment

from beta_rec.recommenders.ncf import NeuCF

# Initialise recommenders with their default configuration file

config = {"config_file": "../configs/ncf_default.json"}

ncf = NeuCF(config)

# Run experiments of the recommenders on the selected dataset

Experiment(datasets=[data], models=[ncf],).run()
# Out:
# loading config file ../configs/ncf_default.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +--------+----------+
# | keys   | values   |
# |--------+----------|
# +--------+----------+
# --------------------------------------------------------------------------------
# logs will save in file: /users/tr.xi/Project_Third_Year/beta-recsys/logs/ncf_default_20201114_231104_cqedqq .stdout.log .stderr.log
# 2020-11-14 23:11:05 [INFO]-
# Python version: 3.6.10 |Anaconda, Inc.| (default, Jan  7 2020, 21:14:29)
# [GCC 7.3.0
# 2020-11-14 23:11:05 [INFO]-
# 2020-11-14 23:11:05 [INFO]-pytorch version: 1.5.1
# 2020-11-14 23:11:05 [INFO]-The intermediate running statuses will be reported in folder: /users/tr.xi/Project_Third_Year/beta-recsys/runs/ncf_default_20201114_231104_cqedqq
# 2020-11-14 23:11:05 [INFO]-Model checkpoint will save in file: /users/tr.xi/Project_Third_Year/beta-recsys/checkpoints/ncf_default_20201114_231104_cqedqq
# 2020-11-14 23:11:05 [INFO]-Performance result will save in file: /users/tr.xi/Project_Third_Year/beta-recsys/results/ncf_result.csv
# 2020-11-14 23:11:05 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:11:05 [INFO]-System configs
# 2020-11-14 23:11:05 [INFO]-
# +----+----------------+--------------------------------------------------------------------------------------------+
# |    | keys           | values                                                                                     |
# |----+----------------+--------------------------------------------------------------------------------------------|
# |  0 | root_dir       | /users/tr.xi/Project_Third_Year/beta-recsys                                                |
# |  1 | log_dir        | logs/                                                                                      |
# |  2 | result_dir     | results/                                                                                   |
# |  3 | process_dir    | /users/tr.xi/Project_Third_Year/beta-recsys/processes/                                     |
# |  4 | checkpoint_dir | checkpoints/                                                                               |
# |  5 | dataset_dir    | datasets/                                                                                  |
# |  6 | run_dir        | /users/tr.xi/Project_Third_Year/beta-recsys/runs/ncf_default_20201114_231104_cqedqq        |
# |  7 | tune_dir       | /users/tr.xi/Project_Third_Year/beta-recsys/tune_results/                                  |
# |  8 | device         | gpu                                                                                        |
# |  9 | seed           | 2020                                                                                       |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                                     |
# | 11 | k              | [5, 10, 20]                                                                                |
# | 12 | valid_metric   | ndcg                                                                                       |
# | 13 | valid_k        | 10                                                                                         |
# | 14 | result_file    | /users/tr.xi/Project_Third_Year/beta-recsys/results/ncf_result.csv                         |
# | 15 | model_run_id   | ncf_default_20201114_231104_cqedqq                                                         |
# | 16 | log_file       | /users/tr.xi/Project_Third_Year/beta-recsys/logs/ncf_default_20201114_231104_cqedqq        |
# | 17 | model_save_dir | /users/tr.xi/Project_Third_Year/beta-recsys/checkpoints/ncf_default_20201114_231104_cqedqq |
# +----+----------------+--------------------------------------------------------------------------------------------
# 2020-11-14 23:11:05 [INFO]-
# 2020-11-14 23:11:05 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:11:06 [INFO]-Find only one gpu with id:  0
# 2020-11-14 23:11:06 [INFO]-port 8003 is available. start_http_server.
# 2020-11-14 23:11:06 [INFO]-Initializing test engine ...
# 2020-11-14 23:11:07 [INFO]-Find only one gpu with id:  0
# 2020-11-14 23:11:07 [INFO]-Setting device for torch_engine cuda:0
# 2020-11-14 23:11:11 [INFO]-
# NeuMF(
#   (embedding_user_mlp): Embedding(943, 128)
#   (embedding_item_mlp): Embedding(1678, 128)
#   (embedding_user_mf): Embedding(943, 32)
#   (embedding_item_mf): Embedding(1678, 32)
#   (fc_layers): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=256, out_features=128, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0.0, inplace=False)
#     (7): Linear(in_features=64, out_features=32, bias=True)
#     (8): ReLU()
#   )
#   (affine_output): Linear(in_features=64, out_features=1, bias=True)
#   (logistic): Sigmoid()
#
# 2020-11-14 23:11:11 [INFO]-
# 2020-11-14 23:11:11 [INFO]-
# NeuMF(
#   (embedding_user_mlp): Embedding(943, 128)
#   (embedding_item_mlp): Embedding(1678, 128)
#   (embedding_user_mf): Embedding(943, 32)
#   (embedding_item_mf): Embedding(1678, 32)
#   (fc_layers): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=256, out_features=128, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0.0, inplace=False)
#     (7): Linear(in_features=64, out_features=32, bias=True)
#     (8): ReLU()
#   )
#   (affine_output): Linear(in_features=64, out_features=1, bias=True)
#   (logistic): Sigmoid()
#
# 2020-11-14 23:11:11 [INFO]-
# 2020-11-14 23:11:34 [INFO]-Making PairwiseNegativeDataset of length 98114
#   0%|          | 0/20 [00:00<?, ?it/s]Epoch 0 starts !
# 2020-11-14 23:11:34 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:11:37 [INFO]-[Training Epoch 0], Loss -90346.8984375
# 2020-11-14 23:11:37 [INFO]-Execute [train_an_epoch] method costing 3419.16 ms
#   5%|5         | 1/20 [00:03<01:14,  3.92s/it]Epoch 1 starts !
# 2020-11-14 23:11:38 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:11:46 [INFO]-Current testEngine.best_valid_performance 0
# 2020-11-14 23:11:46 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:11:46 [INFO]-performance on validation at epoch 0
# 2020-11-14 23:11:46 [INFO]-
# +----+--------------+------------+
# |    | metrics      |     values |
# |----+--------------+------------|
# |  0 | ndcg@10      | 0.042703   |
# |  1 | precision@10 | 0.00998937 |
# |  2 | recall@10    | 0.0998937  |
# |  3 | map@10       | 0.0258329  |
# +----+--------------+------------
# 2020-11-14 23:11:46 [INFO]-
# 2020-11-14 23:11:46 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:11:46 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:11:46 [INFO]-performance on testing at epoch 0
# 2020-11-14 23:11:46 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0459727 |
# |  1 | precision@10 | 0.010627  |
# |  2 | recall@10    | 0.10627   |
# |  3 | map@10       | 0.0283302 |
# +----+--------------+-----------
# 2020-11-14 23:11:46 [INFO]-
# 2020-11-14 23:11:46 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:11:46 [INFO]-Execute [train_eval_worker] method costing 8580.39 ms
# 2020-11-14 23:11:49 [INFO]-[Training Epoch 1], Loss -92292.234375
# 2020-11-14 23:11:49 [INFO]-Execute [train_an_epoch] method costing 10323.03 ms
#  10%|#         | 2/20 [00:14<01:47,  5.98s/it]Epoch 2 starts !
# 2020-11-14 23:11:49 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:11:57 [INFO]-number of epochs that have no update 1
# 2020-11-14 23:11:57 [INFO]-Execute [train_eval_worker] method costing 8202.50 ms
# 2020-11-14 23:11:59 [INFO]-[Training Epoch 2], Loss -93162.421875
# 2020-11-14 23:11:59 [INFO]-Execute [train_an_epoch] method costing 10488.78 ms
#  15%|#5        | 3/20 [00:25<02:05,  7.41s/it]Epoch 3 starts !
# 2020-11-14 23:11:59 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:12:08 [INFO]-number of epochs that have no update 2
# 2020-11-14 23:12:08 [INFO]-Execute [train_eval_worker] method costing 8216.92 ms
# 2020-11-14 23:12:10 [INFO]-[Training Epoch 3], Loss -89831.3671875
# 2020-11-14 23:12:10 [INFO]-Execute [train_an_epoch] method costing 10730.80 ms
#  20%|##        | 4/20 [00:36<02:14,  8.41s/it]Epoch 4 starts !
# 2020-11-14 23:12:10 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:12:19 [INFO]-number of epochs that have no update 3
# 2020-11-14 23:12:19 [INFO]-Execute [train_eval_worker] method costing 8462.46 ms
# 2020-11-14 23:12:21 [INFO]-[Training Epoch 4], Loss -92377.328125
# 2020-11-14 23:12:21 [INFO]-Execute [train_an_epoch] method costing 11041.99 ms
#  25%|##5       | 5/20 [00:47<02:18,  9.21s/it]Epoch 5 starts !
# 2020-11-14 23:12:21 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:12:29 [INFO]-number of epochs that have no update 4
# 2020-11-14 23:12:30 [INFO]-Execute [train_eval_worker] method costing 8293.92 ms
# 2020-11-14 23:12:32 [INFO]-[Training Epoch 5], Loss -86349.6875
# 2020-11-14 23:12:32 [INFO]-Execute [train_an_epoch] method costing 10746.70 ms
#  30%|###       | 6/20 [00:58<02:15,  9.68s/it]Epoch 6 starts !
# 2020-11-14 23:12:32 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:12:40 [INFO]-number of epochs that have no update 5
# 2020-11-14 23:12:40 [INFO]-Execute [train_eval_worker] method costing 7866.41 ms
# 2020-11-14 23:12:42 [INFO]-[Training Epoch 6], Loss -88777.640625
# 2020-11-14 23:12:42 [INFO]-Execute [train_an_epoch] method costing 10304.51 ms
#  35%|###5      | 7/20 [01:08<02:08,  9.87s/it]Epoch 7 starts !
# 2020-11-14 23:12:42 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:12:42 [INFO]-Early stop criterion triggered, no performance update for 5 times
# 2020-11-14 23:12:42 [INFO]-Program running time:89 seconds
# 2020-11-14 23:13:05 [INFO]-number of epochs that have no update 6
# 2020-11-14 23:13:05 [INFO]-Execute [train_eval_worker] method costing 22357.27 ms
# 2020-11-14 23:13:08 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:13:08 [INFO]-performance on test
# 2020-11-14 23:13:08 [INFO]-
# +----+--------------+------------+
# |    | metrics      |     values |
# |----+--------------+------------|
# |  0 | ndcg@5       | 0.0251661  |
# |  1 | precision@5  | 0.00828905 |
# |  2 | recall@5     | 0.0414453  |
# |  3 | map@5        | 0.0198371  |
# |  4 | ndcg@10      | 0.0459727  |
# |  5 | precision@10 | 0.010627   |
# |  6 | recall@10    | 0.10627    |
# |  7 | map@10       | 0.0283302  |
# |  8 | ndcg@20      | 0.0699804  |
# |  9 | precision@20 | 0.0101488  |
# | 10 | recall@20    | 0.202976   |
# | 11 | map@20       | 0.0346926  |
# +----+--------------+------------
# 2020-11-14 23:13:08 [INFO]-
# 2020-11-14 23:13:08 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:13:08 [INFO]-Create new result_file: /users/tr.xi/Project_Third_Year/beta-recsys/results/ncf_result.csv
# 2020-11-14 23:13:08 [INFO]-Execute [test_eval_worker] method costing 25898.16 ms
# 2020-11-14 23:13:08 [INFO]-Execute [test_eval] method costing 25919.76 ms
# 2020-11-14 23:13:08 [INFO]---------------------------------------------------------------------------------
# 2020-11-14 23:13:09 [INFO]-
# +--------------+----------------------+
# |              | ['ncf']              |
# |--------------+----------------------|
# | ndcg@5       | 0.025166054097973085 |
# | precision@5  | 0.008289054197662063 |
# | recall@5     | 0.04144527098831031  |
# | map@5        | 0.01983705278072972  |
# | ndcg@10      | 0.04597272751008216  |
# | precision@10 | 0.010626992561105206 |
# | recall@10    | 0.10626992561105207  |
# | map@10       | 0.028330212708533642 |
# | ndcg@20      | 0.06998043823542664  |
# | precision@20 | 0.010148777895855469 |
# | recall@20    | 0.20297555791710944  |
# | map@20       | 0.03469259699531494  |
# | run_time     | [89.8829562664032]   |
# | emb_dim      | [32]                 |
# | batch_size   | [512]                |
# | optimizer    | ['adam']             |
# | lr           | [0.001]              |
# | dataset      | ['ml_100k']          |
# | data_split   | ['leave_one_out']    |
# | test_rate    | [0.2]                |
# | n_negative   | [100]                |
# +--------------+----------------------
# 2020-11-14 23:13:09 [INFO]-
# 2020-11-14 23:13:09 [INFO]---------------------------------------------------------------------------------
