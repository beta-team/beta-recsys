# %% [markdown]
# ## Loading dataset

# %%
from beta_rec.datasets.tafeng import Tafeng
from beta_rec.data.sequential_data import SequentialData

dataset = Tafeng(min_u_c=30,min_i_c=20,min_o_c=10)
split_dataset = dataset.load_temporal_basket_split(test_rate=0.2)
data = SequentialData(split_dataset)
# Out:
# download_file: url: https://1drv.ms/u/s!AjMahLyQeZqugjc2k3eCAwKavccB?e=Qn5ppw, raw_file_path: /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/raw/tafeng.zip
# Start downloading file s!AjMahLyQeZqugjc2k3eCAwKavccB?e=Qn5ppw with url https://1drv.ms/u/s!AjMahLyQeZqugjc2k3eCAwKavccB?e=Qn5ppw...
# Traversing public folder
#
# Found tafeng.zip
#
# Starting async download
#
# Download progress: 1/1, 100%
# Execute [download] method costing 2507.81 ms
# 405742
# 464118
# 405742
# 464118
# --------------------------------------------------------------------------------
# Raw interaction statistics
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 464118     | 464118     | 464118       | 464118          | 464118      |
# | nunique | 9238       | 7973       | 1            | 120             | 77202       |
# +---------+------------+------------+--------------+-----------------+-------------+
# --------------------------------------------------------------------------------
# filter_user_item_order under condition min_u_c=30, min_i_c=20, min_o_c=10
# --------------------------------------------------------------------------------
# Dataset statistics before filter
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 464118     | 464118     | 464118       | 464118          | 464118      |
# | nunique | 9238       | 7973       | 1            | 120             | 77202       |
# +---------+------------+------------+--------------+-----------------+-------------+
# Dataset statistics after filter
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 88285      | 88285      | 88285        | 88285           | 88285       |
# | nunique | 1539       | 1029       | 1            | 120             | 25440       |
# +---------+------------+------------+--------------+-----------------+-------------+
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Interaction statistics after filtering -- min_u_c:30, min_i_c:20, min_o_c:10.
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 88285      | 88285      | 88285        | 88285           | 88285       |
# | nunique | 1539       | 1029       | 1            | 120             | 25440       |
# +---------+------------+------------+--------------+-----------------+-------------+
# --------------------------------------------------------------------------------
# Splitting data by temporal_basket ...
# temporal_split_basket
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/train.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/valid.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/test.npz
# Filling alias table
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/valid_0.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/test_0.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/valid_1.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/test_1.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/valid_2.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/test_2.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/valid_3.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/test_3.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/valid_4.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/test_4.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/valid_5.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/test_5.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/valid_6.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/test_6.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/valid_7.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/test_7.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/valid_8.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/test_8.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/valid_9.npz
# Data is dumped in : /home/zm324/anaconda3/envs/beta_rec/lib/python3.6/site-packages/datasets/tafeng/processed/temporal_basket/full_test_rate_20_n_neg_100/test_9.npz
# Execute [make_temporal_basket_split] method costing 160355.07 ms
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 53030      | 53030      | 53030        | 53030           | 53030       |
# | nunique | 1539       | 1017       | 1            | 75              | 15264       |
# +---------+------------+------------+--------------+-----------------+-------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 164412     | 164412     | 164412       | 164412          |
# | nunique | 1470       | 1029       | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 162075     | 162075     | 162075       | 162075          |
# | nunique | 1469       | 1029       | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 160023     | 160023     | 160023       | 160023          |
# | nunique | 1469       | 1017       | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 162464     | 162464     | 162464       | 162464          |
# | nunique | 1470       | 1017       | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table

# %% [markdown]
# ### Model config

# %%
config = {"config_file": "../configs/sasrec_default.json",
          "device":"gpu",
          "emb_dim":64,
          "num_blocks": 2,
          "num_heads": 2,
          "lr": 0.5,
          "dropout_rate":0.1
         }
# the 'config_file' key is required, that is used load a default config.
# Other keys can be specified to replace the default settings.

# %% [markdown]
# ### Model intialization and training

# %%
from beta_rec.recommenders import SASRec

model = SASRec(config)
model.train(data)
# Out:
# loading config file ../configs/sasrec_default.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +----+--------------------+----------+
# |    | keys               | values   |
# |----+--------------------+----------|
# |  0 | system:device      | gpu      |
# |  1 | model:emb_dim      | 64       |
# |  2 | model:num_blocks   | 2        |
# |  3 | model:num_heads    | 2        |
# |  4 | model:lr           | 0.5      |
# |  5 | model:dropout_rate | 0.1      |
# +----+--------------------+----------+
# --------------------------------------------------------------------------------
# logs will save in file: /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_212623_xsbnxw .stdout.log .stderr.log
# 2021-01-24 21:26:23 [INFO]-
# Python version: 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# [GCC 7.3.0
# 2021-01-24 21:26:23 [INFO]-
# 2021-01-24 21:26:23 [INFO]-pytorch version: 1.7.1
# 2021-01-24 21:26:23 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_212623_xsbnxw
# 2021-01-24 21:26:23 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_212623_xsbnxw
# 2021-01-24 21:26:23 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/sasrec_result.csv
# 2021-01-24 21:26:23 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:26:23 [INFO]-System configs
# 2021-01-24 21:26:23 [INFO]-
# +----+----------------+-------------------------------------------------------------------------------------+
# |    | keys           | values                                                                              |
# |----+----------------+-------------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                   |
# |  1 | log_dir        | logs/                                                                               |
# |  2 | result_dir     | results/                                                                            |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                        |
# |  4 | checkpoint_dir | checkpoints/                                                                        |
# |  5 | dataset_dir    | datasets/                                                                           |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_212623_xsbnxw        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                     |
# |  8 | device         | gpu                                                                                 |
# |  9 | seed           | 2020                                                                                |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                              |
# | 11 | k              | [5, 10, 20]                                                                         |
# | 12 | valid_metric   | ndcg                                                                                |
# | 13 | valid_k        | 10                                                                                  |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/sasrec_result.csv                         |
# | 15 | save_mode      | average                                                                             |
# | 16 | model_run_id   | SASRec_default_20210124_212623_xsbnxw                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_212623_xsbnxw        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_212623_xsbnxw |
# +----+----------------+-------------------------------------------------------------------------------------
# 2021-01-24 21:26:23 [INFO]-
# 2021-01-24 21:26:23 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:26:23 [INFO]-Get a gpu with the most available memory : 0
# 2021-01-24 21:26:23 [INFO]-[Warning]: port 8003 was already in use.
# 2021-01-24 21:26:23 [INFO]-If you need to use prometheus, please check that port or specify another port number.
# 2021-01-24 21:26:23 [INFO]-Initializing test engine ...
# 2021-01-24 21:26:23 [INFO]-Get a gpu with the most available memory : 0
# 2021-01-24 21:26:23 [INFO]-{'system': {'root_dir': '/home/zm324/workspace/beta-recsys', 'log_dir': 'logs/', 'result_dir': 'results/', 'process_dir': '/home/zm324/workspace/beta-recsys/processes/', 'checkpoint_dir': 'checkpoints/', 'dataset_dir': 'datasets/', 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_212623_xsbnxw', 'tune_dir': '/home/zm324/workspace/beta-recsys/tune_results/', 'device': 'gpu', 'seed': 2020, 'metrics': ['ndcg', 'precision', 'recall', 'map'], 'k': [5, 10, 20], 'valid_metric': 'ndcg', 'valid_k': 10, 'result_file': '/home/zm324/workspace/beta-recsys/results/sasrec_result.csv', 'save_mode': 'average', 'model_run_id': 'SASRec_default_20210124_212623_xsbnxw', 'log_file': '/home/zm324/workspace/beta-recsys/logs/SASRec_default_20210124_212623_xsbnxw', 'model_save_dir': '/home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_212623_xsbnxw'}, 'dataset': {'dataset': 'ml_100k', 'data_split': 'leave_one_out', 'test_rate': 0.2, 'download': False, 'random': False, 'by_user': False, 'n_test': 10, 'n_negative': 100, 'result_col': ['dataset', 'data_split', 'test_rate', 'n_negative']}, 'model': {'model': 'SASRec', 'config_id': 'default', 'emb_dim': 64, 'num_blocks': 2, 'num_heads': 2, 'maxlen': 200, 'lr': 0.5, 'batch_size': 128, 'batch_eval': True, 'dropout_rate': 0.1, 'optimizer': 'adam', 'l2_emb': 0.1, 'max_epoch': 200, 'max_n_update': 20, 'save_name': 'sasrec.model', 'result_col': ['model', 'emb_dim', 'batch_size', 'maxlen', 'optimizer', 'lr', 'l2_emb'], 'run_dir': '/home/zm324/workspace/beta-recsys/runs/SASRec_default_20210124_212623_xsbnxw', 'device_str': 'cuda:0', 'n_users': 1539, 'n_items': 1017}, 'tunable': [{'name': 'emb_dim', 'type': 'choice', 'values': [32, 64]}, {'name': 'lr', 'type': 'choice', 'values': [1, 0.5, 0.3, 0.1, 0.001]}, {'name': 'lrnum_heads', 'type': 'choice', 'values': [1, 2]}, {'name': 'l2_emb', 'type': 'choice', 'values': [0.0001, 0.001, 0.01, 0.1, 1]}], 'device_str': 'cuda:0'}
# 2021-01-24 21:26:23 [INFO]-Setting device for torch_engine cuda:0
# 2021-01-24 21:26:26 [INFO]-
# SASRec(
#   (item_emb): Embedding(1018, 64, padding_idx=0)
#   (pos_emb): Embedding(200, 64)
#   (emb_dropout): Dropout(p=0.1, inplace=False)
#   (attention_layernorms): ModuleList(
#     (0): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     (1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#   )
#   (attention_layers): ModuleList(
#     (0): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=64, out_features=64, bias=True)
#     )
#     (1): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (forward_layernorms): ModuleList(
#     (0): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     (1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#   )
#   (forward_layers): ModuleList(
#     (0): PointWiseFeedForward(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#       (conv2): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (dropout2): Dropout(p=0.1, inplace=False)
#     )
#     (1): PointWiseFeedForward(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (relu): ReLU()
#       (conv2): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (dropout2): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (last_layernorm): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#
# 2021-01-24 21:26:26 [INFO]-
#   0%|          | 0/200 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-01-24 21:26:28 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:26:29 [INFO]-[Training Epoch 0], Loss 247.7777442932129
#   0%|          | 1/200 [00:10<35:03, 10.57s/it]Epoch 1 starts !
# 2021-01-24 21:26:39 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:26:47 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 21:26:47 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:26:47 [INFO]-performance on validation at epoch 0
# 2021-01-24 21:26:47 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.114069  |
# |  1 | precision@10 | 0.103605  |
# |  2 | recall@10    | 0.0950202 |
# |  3 | map@10       | 0.0340904 |
# +----+--------------+-----------
# 2021-01-24 21:26:47 [INFO]-
# 2021-01-24 21:26:47 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:26:47 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:26:47 [INFO]-performance on testing at epoch 0
# 2021-01-24 21:26:47 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.110862  |
# |  1 | precision@10 | 0.0967984 |
# |  2 | recall@10    | 0.0973034 |
# |  3 | map@10       | 0.0358562 |
# +----+--------------+-----------
# 2021-01-24 21:26:47 [INFO]-
# 2021-01-24 21:26:47 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:26:47 [INFO]-Execute [train_eval_worker] method costing 8593.00 ms
# 2021-01-24 21:26:48 [INFO]-[Training Epoch 1], Loss 115.62407922744751
#   1%|1         | 2/200 [00:28<41:52, 12.69s/it]Epoch 2 starts !
# 2021-01-24 21:26:56 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:27:05 [INFO]-Current testEngine.best_valid_performance 0.11406911538285942
# 2021-01-24 21:27:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:27:05 [INFO]-performance on validation at epoch 1
# 2021-01-24 21:27:05 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.120954  |
# |  1 | precision@10 | 0.106667  |
# |  2 | recall@10    | 0.0982409 |
# |  3 | map@10       | 0.0363578 |
# +----+--------------+-----------
# 2021-01-24 21:27:05 [INFO]-
# 2021-01-24 21:27:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:27:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:27:05 [INFO]-performance on testing at epoch 1
# 2021-01-24 21:27:05 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.114951  |
# |  1 | precision@10 | 0.0993188 |
# |  2 | recall@10    | 0.103288  |
# |  3 | map@10       | 0.0380042 |
# +----+--------------+-----------
# 2021-01-24 21:27:05 [INFO]-
# 2021-01-24 21:27:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:27:05 [INFO]-Execute [train_eval_worker] method costing 8603.07 ms
# 2021-01-24 21:27:05 [INFO]-[Training Epoch 2], Loss 67.72053241729736
#   2%|1         | 3/200 [00:47<47:41, 14.53s/it]Epoch 3 starts !
# 2021-01-24 21:27:15 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:27:24 [INFO]-Current testEngine.best_valid_performance 0.1209536139234492
# 2021-01-24 21:27:24 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:27:24 [INFO]-performance on validation at epoch 2
# 2021-01-24 21:27:24 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.129475  |
# |  1 | precision@10 | 0.115442  |
# |  2 | recall@10    | 0.108175  |
# |  3 | map@10       | 0.0413241 |
# +----+--------------+-----------
# 2021-01-24 21:27:24 [INFO]-
# 2021-01-24 21:27:24 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:27:24 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:27:24 [INFO]-performance on testing at epoch 2
# 2021-01-24 21:27:24 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.11508   |
# |  1 | precision@10 | 0.100749  |
# |  2 | recall@10    | 0.104557  |
# |  3 | map@10       | 0.0385076 |
# +----+--------------+-----------
# 2021-01-24 21:27:24 [INFO]-
# 2021-01-24 21:27:24 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:27:24 [INFO]-Execute [train_eval_worker] method costing 8655.87 ms
# 2021-01-24 21:27:24 [INFO]-[Training Epoch 3], Loss 44.14405798912048
#   2%|2         | 4/200 [01:04<50:37, 15.50s/it]Epoch 4 starts !
# 2021-01-24 21:27:33 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:27:41 [INFO]-number of epochs that have no update 1
# 2021-01-24 21:27:41 [INFO]-Execute [train_eval_worker] method costing 8541.75 ms
# 2021-01-24 21:27:42 [INFO]-[Training Epoch 4], Loss 32.0585196018219
#   2%|2         | 5/200 [01:23<53:40, 16.51s/it]Epoch 5 starts !
# 2021-01-24 21:27:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:28:00 [INFO]-number of epochs that have no update 2
# 2021-01-24 21:28:00 [INFO]-Execute [train_eval_worker] method costing 8590.82 ms
# 2021-01-24 21:28:01 [INFO]-[Training Epoch 5], Loss 28.503324031829834
#   3%|3         | 6/200 [01:41<54:31, 16.86s/it]Epoch 6 starts !
# 2021-01-24 21:28:10 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:28:18 [INFO]-number of epochs that have no update 3
# 2021-01-24 21:28:18 [INFO]-Execute [train_eval_worker] method costing 8774.04 ms
# 2021-01-24 21:28:19 [INFO]-[Training Epoch 6], Loss 26.427616357803345
#   4%|3         | 7/200 [02:00<56:23, 17.53s/it]Epoch 7 starts !
# 2021-01-24 21:28:29 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:28:37 [INFO]-number of epochs that have no update 4
# 2021-01-24 21:28:37 [INFO]-Execute [train_eval_worker] method costing 8609.88 ms
# 2021-01-24 21:28:38 [INFO]-[Training Epoch 7], Loss 26.316981077194214
#   4%|4         | 8/200 [02:18<56:10, 17.55s/it]Epoch 8 starts !
# 2021-01-24 21:28:46 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:28:55 [INFO]-number of epochs that have no update 5
# 2021-01-24 21:28:55 [INFO]-Execute [train_eval_worker] method costing 8747.00 ms
# 2021-01-24 21:28:55 [INFO]-[Training Epoch 8], Loss 25.09512448310852
#   4%|4         | 9/200 [02:37<57:20, 18.01s/it]Epoch 9 starts !
# 2021-01-24 21:29:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:29:14 [INFO]-number of epochs that have no update 6
# 2021-01-24 21:29:14 [INFO]-Execute [train_eval_worker] method costing 8694.93 ms
# 2021-01-24 21:29:14 [INFO]-[Training Epoch 9], Loss 25.21008062362671
#   5%|5         | 10/200 [02:54<56:48, 17.94s/it]Epoch 10 starts !
# 2021-01-24 21:29:23 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:29:32 [INFO]-Current testEngine.best_valid_performance 0.12947467487632097
# 2021-01-24 21:29:32 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:29:32 [INFO]-performance on validation at epoch 9
# 2021-01-24 21:29:32 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.141317  |
# |  1 | precision@10 | 0.125102  |
# |  2 | recall@10    | 0.117392  |
# |  3 | map@10       | 0.0434886 |
# +----+--------------+-----------
# 2021-01-24 21:29:32 [INFO]-
# 2021-01-24 21:29:32 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:29:32 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:29:32 [INFO]-performance on testing at epoch 9
# 2021-01-24 21:29:32 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.0993433 |
# |  1 | precision@10 | 0.0854223 |
# |  2 | recall@10    | 0.0900891 |
# |  3 | map@10       | 0.0319563 |
# +----+--------------+-----------
# 2021-01-24 21:29:32 [INFO]-
# 2021-01-24 21:29:32 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:29:32 [INFO]-Execute [train_eval_worker] method costing 8674.20 ms
# 2021-01-24 21:29:32 [INFO]-[Training Epoch 10], Loss 25.56197738647461
#   6%|5         | 11/200 [03:13<57:16, 18.18s/it]Epoch 11 starts !
# 2021-01-24 21:29:42 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:29:51 [INFO]-number of epochs that have no update 1
# 2021-01-24 21:29:51 [INFO]-Execute [train_eval_worker] method costing 8739.64 ms
# 2021-01-24 21:29:51 [INFO]-[Training Epoch 11], Loss 24.877750873565674
#   6%|6         | 12/200 [03:31<56:34, 18.05s/it]Epoch 12 starts !
# 2021-01-24 21:30:00 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:30:08 [INFO]-number of epochs that have no update 2
# 2021-01-24 21:30:08 [INFO]-Execute [train_eval_worker] method costing 8707.04 ms
# 2021-01-24 21:30:09 [INFO]-[Training Epoch 12], Loss 24.928669691085815
#   6%|6         | 13/200 [03:50<56:58, 18.28s/it]Epoch 13 starts !
# 2021-01-24 21:30:18 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:30:27 [INFO]-number of epochs that have no update 3
# 2021-01-24 21:30:27 [INFO]-Execute [train_eval_worker] method costing 8535.29 ms
# 2021-01-24 21:30:27 [INFO]-[Training Epoch 13], Loss 24.962688207626343
#   7%|7         | 14/200 [04:07<55:56, 18.05s/it]Epoch 14 starts !
# 2021-01-24 21:30:36 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:30:45 [INFO]-number of epochs that have no update 4
# 2021-01-24 21:30:45 [INFO]-Execute [train_eval_worker] method costing 8809.91 ms
# 2021-01-24 21:30:45 [INFO]-[Training Epoch 14], Loss 24.957876682281494
#   8%|7         | 15/200 [04:26<56:37, 18.36s/it]Epoch 15 starts !
# 2021-01-24 21:30:55 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:31:04 [INFO]-number of epochs that have no update 5
# 2021-01-24 21:31:04 [INFO]-Execute [train_eval_worker] method costing 8714.16 ms
# 2021-01-24 21:31:04 [INFO]-[Training Epoch 15], Loss 25.18339729309082
#   8%|8         | 16/200 [04:44<55:45, 18.18s/it]Epoch 16 starts !
# 2021-01-24 21:31:13 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:31:22 [INFO]-number of epochs that have no update 6
# 2021-01-24 21:31:22 [INFO]-Execute [train_eval_worker] method costing 8812.32 ms
# 2021-01-24 21:31:22 [INFO]-[Training Epoch 16], Loss 25.1389262676239
#   8%|8         | 17/200 [05:03<56:24, 18.49s/it]Epoch 17 starts !
# 2021-01-24 21:31:32 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:31:41 [INFO]-number of epochs that have no update 7
# 2021-01-24 21:31:41 [INFO]-Execute [train_eval_worker] method costing 8674.42 ms
# 2021-01-24 21:31:41 [INFO]-[Training Epoch 17], Loss 25.216339826583862
#   9%|9         | 18/200 [05:21<55:22, 18.25s/it]Epoch 18 starts !
# 2021-01-24 21:31:50 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:31:58 [INFO]-number of epochs that have no update 8
# 2021-01-24 21:31:58 [INFO]-Execute [train_eval_worker] method costing 8637.63 ms
# 2021-01-24 21:31:59 [INFO]-[Training Epoch 18], Loss 25.24338436126709
#  10%|9         | 19/200 [05:40<55:46, 18.49s/it]Epoch 19 starts !
# 2021-01-24 21:32:09 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:32:17 [INFO]-number of epochs that have no update 9
# 2021-01-24 21:32:17 [INFO]-Execute [train_eval_worker] method costing 8624.10 ms
# 2021-01-24 21:32:18 [INFO]-[Training Epoch 19], Loss 24.75984835624695
#  10%|#         | 20/200 [05:58<54:45, 18.25s/it]Epoch 20 starts !
# 2021-01-24 21:32:26 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:32:35 [INFO]-number of epochs that have no update 10
# 2021-01-24 21:32:35 [INFO]-Execute [train_eval_worker] method costing 8820.75 ms
# 2021-01-24 21:32:36 [INFO]-[Training Epoch 20], Loss 25.324419260025024
#  10%|#         | 21/200 [06:17<55:19, 18.54s/it]Epoch 21 starts !
# 2021-01-24 21:32:46 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:32:54 [INFO]-number of epochs that have no update 11
# 2021-01-24 21:32:54 [INFO]-Execute [train_eval_worker] method costing 8543.31 ms
# 2021-01-24 21:32:55 [INFO]-[Training Epoch 21], Loss 24.37494969367981
#  11%|#1        | 22/200 [06:35<54:12, 18.27s/it]Epoch 22 starts !
# 2021-01-24 21:33:03 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:33:12 [INFO]-number of epochs that have no update 12
# 2021-01-24 21:33:12 [INFO]-Execute [train_eval_worker] method costing 8635.45 ms
# 2021-01-24 21:33:12 [INFO]-[Training Epoch 22], Loss 25.539896488189697
#  12%|#1        | 23/200 [06:53<54:13, 18.38s/it]Epoch 23 starts !
# 2021-01-24 21:33:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:33:30 [INFO]-number of epochs that have no update 13
# 2021-01-24 21:33:30 [INFO]-Execute [train_eval_worker] method costing 8610.32 ms
# 2021-01-24 21:33:31 [INFO]-[Training Epoch 23], Loss 24.480717182159424
#  12%|#2        | 24/200 [07:11<53:17, 18.17s/it]Epoch 24 starts !
# 2021-01-24 21:33:40 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:33:48 [INFO]-number of epochs that have no update 14
# 2021-01-24 21:33:48 [INFO]-Execute [train_eval_worker] method costing 8838.17 ms
# 2021-01-24 21:33:49 [INFO]-[Training Epoch 24], Loss 25.53187870979309
#  12%|#2        | 25/200 [07:30<53:48, 18.45s/it]Epoch 25 starts !
# 2021-01-24 21:33:59 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:34:07 [INFO]-Current testEngine.best_valid_performance 0.1413167197660631
# 2021-01-24 21:34:07 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:34:07 [INFO]-performance on validation at epoch 24
# 2021-01-24 21:34:07 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.142949  |
# |  1 | precision@10 | 0.124014  |
# |  2 | recall@10    | 0.121976  |
# |  3 | map@10       | 0.0452069 |
# +----+--------------+-----------
# 2021-01-24 21:34:07 [INFO]-
# 2021-01-24 21:34:07 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:34:07 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:34:07 [INFO]-performance on testing at epoch 24
# 2021-01-24 21:34:07 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.11201   |
# |  1 | precision@10 | 0.0963896 |
# |  2 | recall@10    | 0.101932  |
# |  3 | map@10       | 0.0378398 |
# +----+--------------+-----------
# 2021-01-24 21:34:07 [INFO]-
# 2021-01-24 21:34:07 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:34:07 [INFO]-Execute [train_eval_worker] method costing 8613.41 ms
# 2021-01-24 21:34:08 [INFO]-[Training Epoch 25], Loss 25.566060543060303
#  13%|#3        | 26/200 [07:48<53:28, 18.44s/it]Epoch 26 starts !
# 2021-01-24 21:34:17 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:34:26 [INFO]-number of epochs that have no update 1
# 2021-01-24 21:34:26 [INFO]-Execute [train_eval_worker] method costing 8756.39 ms
# 2021-01-24 21:34:26 [INFO]-[Training Epoch 26], Loss 25.25394344329834
#  14%|#3        | 27/200 [08:07<53:39, 18.61s/it]Epoch 27 starts !
# 2021-01-24 21:34:36 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:34:45 [INFO]-number of epochs that have no update 2
# 2021-01-24 21:34:45 [INFO]-Execute [train_eval_worker] method costing 8614.01 ms
# 2021-01-24 21:34:45 [INFO]-[Training Epoch 27], Loss 25.068920850753784
#  14%|#4        | 28/200 [08:25<52:21, 18.26s/it]Epoch 28 starts !
# 2021-01-24 21:34:54 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:35:02 [INFO]-number of epochs that have no update 3
# 2021-01-24 21:35:02 [INFO]-Execute [train_eval_worker] method costing 8690.65 ms
# 2021-01-24 21:35:03 [INFO]-[Training Epoch 28], Loss 25.044853448867798
#  14%|#4        | 29/200 [08:42<51:08, 17.95s/it]Epoch 29 starts !
# 2021-01-24 21:35:11 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:35:19 [INFO]-number of epochs that have no update 4
# 2021-01-24 21:35:19 [INFO]-Execute [train_eval_worker] method costing 8233.42 ms
# 2021-01-24 21:35:19 [INFO]-[Training Epoch 29], Loss 25.138850450515747
#  15%|#5        | 30/200 [09:00<50:41, 17.89s/it]Epoch 30 starts !
# 2021-01-24 21:35:29 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:35:37 [INFO]-number of epochs that have no update 5
# 2021-01-24 21:35:37 [INFO]-Execute [train_eval_worker] method costing 8374.54 ms
# 2021-01-24 21:35:37 [INFO]-[Training Epoch 30], Loss 25.16083788871765
#  16%|#5        | 31/200 [09:17<49:31, 17.58s/it]Epoch 31 starts !
# 2021-01-24 21:35:45 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:35:54 [INFO]-number of epochs that have no update 6
# 2021-01-24 21:35:54 [INFO]-Execute [train_eval_worker] method costing 8205.39 ms
# 2021-01-24 21:35:54 [INFO]-[Training Epoch 31], Loss 24.64789128303528
#  16%|#6        | 32/200 [09:33<48:29, 17.32s/it]Epoch 32 starts !
# 2021-01-24 21:36:02 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:36:10 [INFO]-number of epochs that have no update 7
# 2021-01-24 21:36:10 [INFO]-Execute [train_eval_worker] method costing 8181.87 ms
# 2021-01-24 21:36:11 [INFO]-[Training Epoch 32], Loss 25.288676738739014
#  16%|#6        | 33/200 [09:50<47:44, 17.15s/it]Epoch 33 starts !
# 2021-01-24 21:36:19 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:36:27 [INFO]-number of epochs that have no update 8
# 2021-01-24 21:36:27 [INFO]-Execute [train_eval_worker] method costing 8357.87 ms
# 2021-01-24 21:36:28 [INFO]-[Training Epoch 33], Loss 24.86073660850525
#  17%|#7        | 34/200 [10:07<47:16, 17.09s/it]Epoch 34 starts !
# 2021-01-24 21:36:36 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:36:44 [INFO]-number of epochs that have no update 9
# 2021-01-24 21:36:44 [INFO]-Execute [train_eval_worker] method costing 8183.62 ms
# 2021-01-24 21:36:44 [INFO]-[Training Epoch 34], Loss 25.384844064712524
#  18%|#7        | 35/200 [10:24<46:35, 16.94s/it]Epoch 35 starts !
# 2021-01-24 21:36:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:37:01 [INFO]-number of epochs that have no update 10
# 2021-01-24 21:37:01 [INFO]-Execute [train_eval_worker] method costing 8153.35 ms
# 2021-01-24 21:37:01 [INFO]-[Training Epoch 35], Loss 25.22022032737732
#  18%|#8        | 36/200 [10:41<46:19, 16.95s/it]Epoch 36 starts !
# 2021-01-24 21:37:09 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:37:18 [INFO]-number of epochs that have no update 11
# 2021-01-24 21:37:18 [INFO]-Execute [train_eval_worker] method costing 8412.35 ms
# 2021-01-24 21:37:18 [INFO]-[Training Epoch 36], Loss 25.179868459701538
#  18%|#8        | 37/200 [10:58<46:11, 17.00s/it]Epoch 37 starts !
# 2021-01-24 21:37:26 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:37:35 [INFO]-number of epochs that have no update 12
# 2021-01-24 21:37:35 [INFO]-Execute [train_eval_worker] method costing 8428.52 ms
# 2021-01-24 21:37:35 [INFO]-[Training Epoch 37], Loss 25.01812744140625
#  19%|#9        | 38/200 [11:15<46:02, 17.05s/it]Epoch 38 starts !
# 2021-01-24 21:37:44 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:37:52 [INFO]-number of epochs that have no update 13
# 2021-01-24 21:37:52 [INFO]-Execute [train_eval_worker] method costing 8435.89 ms
# 2021-01-24 21:37:53 [INFO]-[Training Epoch 38], Loss 25.364561557769775
#  20%|#9        | 39/200 [11:32<45:49, 17.08s/it]Epoch 39 starts !
# 2021-01-24 21:38:01 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:38:09 [INFO]-number of epochs that have no update 14
# 2021-01-24 21:38:09 [INFO]-Execute [train_eval_worker] method costing 8321.24 ms
# 2021-01-24 21:38:09 [INFO]-[Training Epoch 39], Loss 25.277772903442383
#  20%|##        | 40/200 [11:49<45:32, 17.08s/it]Epoch 40 starts !
# 2021-01-24 21:38:18 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:38:26 [INFO]-number of epochs that have no update 15
# 2021-01-24 21:38:26 [INFO]-Execute [train_eval_worker] method costing 8329.80 ms
# 2021-01-24 21:38:27 [INFO]-[Training Epoch 40], Loss 25.402578830718994
#  20%|##        | 41/200 [12:06<45:16, 17.08s/it]Epoch 41 starts !
# 2021-01-24 21:38:35 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:38:43 [INFO]-number of epochs that have no update 16
# 2021-01-24 21:38:43 [INFO]-Execute [train_eval_worker] method costing 8368.53 ms
# 2021-01-24 21:38:44 [INFO]-[Training Epoch 41], Loss 24.993942975997925
#  21%|##1       | 42/200 [12:23<44:57, 17.07s/it]Epoch 42 starts !
# 2021-01-24 21:38:52 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:39:00 [INFO]-number of epochs that have no update 17
# 2021-01-24 21:39:00 [INFO]-Execute [train_eval_worker] method costing 8371.95 ms
# 2021-01-24 21:39:01 [INFO]-[Training Epoch 42], Loss 25.22559928894043
#  22%|##1       | 43/200 [12:40<44:35, 17.04s/it]Epoch 43 starts !
# 2021-01-24 21:39:09 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:39:17 [INFO]-number of epochs that have no update 18
# 2021-01-24 21:39:17 [INFO]-Execute [train_eval_worker] method costing 8421.05 ms
# 2021-01-24 21:39:18 [INFO]-[Training Epoch 43], Loss 25.62397003173828
#  22%|##2       | 44/200 [12:57<44:25, 17.09s/it]Epoch 44 starts !
# 2021-01-24 21:39:26 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:39:35 [INFO]-number of epochs that have no update 19
# 2021-01-24 21:39:35 [INFO]-Execute [train_eval_worker] method costing 8423.16 ms
# 2021-01-24 21:39:35 [INFO]-[Training Epoch 44], Loss 25.200204372406006
#  22%|##2       | 45/200 [13:15<44:08, 17.09s/it]Epoch 45 starts !
# 2021-01-24 21:39:43 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:39:52 [INFO]-number of epochs that have no update 20
# 2021-01-24 21:39:52 [INFO]-Execute [train_eval_worker] method costing 8470.49 ms
# 2021-01-24 21:39:52 [INFO]-[Training Epoch 45], Loss 25.131972312927246
#  23%|##3       | 46/200 [13:32<43:57, 17.13s/it]Epoch 46 starts !
# 2021-01-24 21:40:00 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 21:40:00 [INFO]-Early stop criterion triggered, no performance update for 20 times
#  23%|##3       | 46/200 [13:32<45:19, 17.66s/it]
# 2021-01-24 21:40:00 [INFO]-Program running time:814 seconds
# {'valid_metric': 0.14294878423339916,
#  'model_save_dir': '/home/zm324/workspace/beta-recsys/checkpoints/SASRec_default_20210124_212623_xsbnxw/sasrec.model'}
# 2021-01-24 21:40:08 [INFO]-number of epochs that have no update 21
# 2021-01-24 21:40:08 [INFO]-Execute [train_eval_worker] method costing 7615.43 ms

# %% [markdown]
# ### Model Tunning

# %%
from beta_rec.recommenders import SASRec
from beta_rec.datasets.movielens import Movielens_1m,Movielens_100k
from beta_rec.data.sequential_data import SequentialData

dataset = Movielens_100k()
split_dataset = dataset.load_leave_one_out(n_test=1)
data = SequentialData(split_dataset)


config = {"config_file": "./sasrec_default.json",
          "device":"gpu",
          "tune":True
         }
model = SASRec(config)
model.train(data)
