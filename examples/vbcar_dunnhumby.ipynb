# %% [markdown]
# ## Loading dataset

# %%
from beta_rec.datasets.dunnhumby import Dunnhumby
from beta_rec.data.grocery_data import GroceryData

dataset = Dunnhumby(min_u_c=30,min_i_c=20,min_o_c=10)
split_dataset = dataset.load_temporal_basket_split(test_rate=0.2)
data = GroceryData(split_dataset)
# Out:
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 1204057    | 1204057    | 1204057      | 1204057         | 1204057     |
# | nunique | 2351       | 11166      | 1            | 125058          | 152982      |
# +---------+------------+------------+--------------+-----------------+-------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 513526     | 513526     | 513526       | 513526          |
# | nunique | 2276       | 11138      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 525646     | 525646     | 525646       | 525646          |
# | nunique | 2299       | 11123      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 524724     | 524724     | 524724       | 524724          |
# | nunique | 2295       | 11116      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 512824     | 512824     | 512824       | 512824          |
# | nunique | 2273       | 11131      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table

# %% [markdown]
# ### Model config

# %%
config = {"config_file": "../configs/vbcar_default.json",
          "device":"gpu",
         }
# the 'config_file' key is required, that is used load a default config.
# Other keys can be specified to replace the default settings.

# %% [markdown]
# ### Model intialization and training

# %%
from beta_rec.recommenders import VBCAR

model = VBCAR(config)
model.train(data)
# Out:
# loading config file ../configs/vbcar_default.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +----+---------------+----------+
# |    | keys          | values   |
# |----+---------------+----------|
# |  0 | system:device | gpu      |
# +----+---------------+----------+
# --------------------------------------------------------------------------------
# logs will save in file: /home/zm324/workspace/beta-recsys/logs/VBCAR_default_20210124_221607_ldzury .stdout.log .stderr.log
# 2021-01-24 22:16:07 [INFO]-
# Python version: 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# [GCC 7.3.0
# 2021-01-24 22:16:07 [INFO]-
# 2021-01-24 22:16:07 [INFO]-pytorch version: 1.7.1
# 2021-01-24 22:16:07 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/VBCAR_default_20210124_221607_ldzury
# 2021-01-24 22:16:07 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/VBCAR_default_20210124_221607_ldzury
# 2021-01-24 22:16:07 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/vbcar_result.csv
# 2021-01-24 22:16:07 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:16:07 [INFO]-System configs
# 2021-01-24 22:16:07 [INFO]-
# +----+----------------+------------------------------------------------------------------------------------+
# |    | keys           | values                                                                             |
# |----+----------------+------------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                  |
# |  1 | log_dir        | logs/                                                                              |
# |  2 | result_dir     | results/                                                                           |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                       |
# |  4 | checkpoint_dir | checkpoints/                                                                       |
# |  5 | dataset_dir    | datasets/                                                                          |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/VBCAR_default_20210124_221607_ldzury        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                    |
# |  8 | device         | gpu                                                                                |
# |  9 | seed           | 2020                                                                               |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                             |
# | 11 | k              | [5, 10, 20]                                                                        |
# | 12 | valid_metric   | ndcg                                                                               |
# | 13 | valid_k        | 10                                                                                 |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/vbcar_result.csv                         |
# | 15 | save_mode      | average                                                                            |
# | 16 | model_run_id   | VBCAR_default_20210124_221607_ldzury                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/VBCAR_default_20210124_221607_ldzury        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/VBCAR_default_20210124_221607_ldzury |
# +----+----------------+------------------------------------------------------------------------------------
# 2021-01-24 22:16:07 [INFO]-
# 2021-01-24 22:16:07 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:16:07 [INFO]-Get a gpu with the most available memory : 0
# 2021-01-24 22:16:07 [INFO]-[Warning]: port 8003 was already in use.
# 2021-01-24 22:16:07 [INFO]-If you need to use prometheus, please check that port or specify another port number.
# 2021-01-24 22:16:07 [INFO]-Initializing test engine ...
# 2021-01-24 22:16:07 [INFO]-Get a gpu with the most available memory : 0
# 2021-01-24 22:16:10 [INFO]-Setting device for torch_engine cuda:0
# 2021-01-24 22:16:10 [INFO]-
# VBCAR(
#   (user_emb): Embedding(2351, 64)
#   (item_emb): Embedding(11166, 64)
#   (fc_u_1_mu): Linear(in_features=512, out_features=256, bias=True)
#   (fc_u_2_mu): Linear(in_features=256, out_features=128, bias=True)
#   (fc_i_1_mu): Linear(in_features=512, out_features=256, bias=True)
#   (fc_i_2_mu): Linear(in_features=256, out_features=128, bias=True)
#
# 2021-01-24 22:16:10 [INFO]-
# 2021-01-24 22:16:12 [INFO]-Initialize Sampler!
# 2021-01-24 22:16:12 [INFO]-Preparing training triples ...
# 100%|##########| 100000/100000 [00:15<00:00, 6622.39it/s]
# 2021-01-24 22:16:39 [INFO]-done!
#   0%|          | 0/200 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-01-24 22:16:39 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:16:53 [INFO]-[Training Epoch 0], log_like_loss 17.30293207615614 kl_loss: 1.4128179233521223 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:16:53 [INFO]-Execute [train_an_epoch] method costing 13640.98 ms
#   0%|          | 1/200 [00:13<46:18, 13.96s/it]Epoch 1 starts !
# 2021-01-24 22:16:53 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:14 [INFO]-Current testEngine.best_valid_performance 0
# 2021-01-24 22:17:14 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:14 [INFO]-performance on validation at epoch 0
# 2021-01-24 22:17:14 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.510832  |
# |  1 | precision@10 | 0.500176  |
# |  2 | recall@10    | 0.0612826 |
# |  3 | map@10       | 0.0370364 |
# +----+--------------+-----------
# 2021-01-24 22:17:14 [INFO]-
# 2021-01-24 22:17:14 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:14 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:14 [INFO]-performance on testing at epoch 0
# 2021-01-24 22:17:14 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.504872  |
# |  1 | precision@10 | 0.49695   |
# |  2 | recall@10    | 0.0572725 |
# |  3 | map@10       | 0.034296  |
# +----+--------------+-----------
# 2021-01-24 22:17:14 [INFO]-
# 2021-01-24 22:17:14 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:14 [INFO]-Execute [train_eval_worker] method costing 21177.97 ms
# 2021-01-24 22:17:29 [INFO]-[Training Epoch 1], log_like_loss 12.20566307194531 kl_loss: 4.764752230606973 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:17:29 [INFO]-Execute [train_an_epoch] method costing 35492.87 ms
#   1%|1         | 2/200 [00:49<1:07:47, 20.54s/it]Epoch 2 starts !
# 2021-01-24 22:17:29 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:50 [INFO]-Current testEngine.best_valid_performance 0.5108315472654457
# 2021-01-24 22:17:50 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:50 [INFO]-performance on validation at epoch 1
# 2021-01-24 22:17:50 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.547197  |
# |  1 | precision@10 | 0.530092  |
# |  2 | recall@10    | 0.0661688 |
# |  3 | map@10       | 0.0424672 |
# +----+--------------+-----------
# 2021-01-24 22:17:50 [INFO]-
# 2021-01-24 22:17:50 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:50 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:50 [INFO]-performance on testing at epoch 1
# 2021-01-24 22:17:50 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.540097  |
# |  1 | precision@10 | 0.525142  |
# |  2 | recall@10    | 0.0637147 |
# |  3 | map@10       | 0.0397141 |
# +----+--------------+-----------
# 2021-01-24 22:17:50 [INFO]-
# 2021-01-24 22:17:50 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:17:50 [INFO]-Execute [train_eval_worker] method costing 21273.47 ms
# 2021-01-24 22:18:05 [INFO]-[Training Epoch 2], log_like_loss 11.724600225687027 kl_loss: 8.456447571516037 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:18:05 [INFO]-Execute [train_an_epoch] method costing 35795.35 ms
#   2%|1         | 3/200 [01:26<1:22:50, 25.23s/it]Epoch 3 starts !
# 2021-01-24 22:18:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:18:27 [INFO]-Current testEngine.best_valid_performance 0.5471970852304775
# 2021-01-24 22:18:27 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:18:27 [INFO]-performance on validation at epoch 2
# 2021-01-24 22:18:27 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.564933  |
# |  1 | precision@10 | 0.546458  |
# |  2 | recall@10    | 0.0685434 |
# |  3 | map@10       | 0.0451876 |
# +----+--------------+-----------
# 2021-01-24 22:18:27 [INFO]-
# 2021-01-24 22:18:27 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:18:27 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:18:27 [INFO]-performance on testing at epoch 2
# 2021-01-24 22:18:27 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.559312  |
# |  1 | precision@10 | 0.543312  |
# |  2 | recall@10    | 0.065009  |
# |  3 | map@10       | 0.0423538 |
# +----+--------------+-----------
# 2021-01-24 22:18:27 [INFO]-
# 2021-01-24 22:18:27 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:18:27 [INFO]-Execute [train_eval_worker] method costing 21329.92 ms
# 2021-01-24 22:18:41 [INFO]-[Training Epoch 3], log_like_loss 11.319808697327971 kl_loss: 11.332608671858907 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:18:41 [INFO]-Execute [train_an_epoch] method costing 35500.22 ms
#   2%|2         | 4/200 [02:01<1:32:52, 28.43s/it]Epoch 4 starts !
# 2021-01-24 22:18:41 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:19:02 [INFO]-Current testEngine.best_valid_performance 0.564933282105977
# 2021-01-24 22:19:02 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:19:02 [INFO]-performance on validation at epoch 3
# 2021-01-24 22:19:02 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.578759  |
# |  1 | precision@10 | 0.556929  |
# |  2 | recall@10    | 0.0691278 |
# |  3 | map@10       | 0.0474718 |
# +----+--------------+-----------
# 2021-01-24 22:19:02 [INFO]-
# 2021-01-24 22:19:02 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:19:03 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:19:03 [INFO]-performance on testing at epoch 3
# 2021-01-24 22:19:03 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.570933  |
# |  1 | precision@10 | 0.551068  |
# |  2 | recall@10    | 0.0680954 |
# |  3 | map@10       | 0.0446623 |
# +----+--------------+-----------
# 2021-01-24 22:19:03 [INFO]-
# 2021-01-24 22:19:03 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:19:03 [INFO]-Execute [train_eval_worker] method costing 21408.98 ms
# 2021-01-24 22:19:17 [INFO]-[Training Epoch 4], log_like_loss 10.993314828723669 kl_loss: 12.82416108623147 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:19:17 [INFO]-Execute [train_an_epoch] method costing 35931.00 ms
#   2%|2         | 5/200 [02:38<1:40:04, 30.79s/it]Epoch 5 starts !
# 2021-01-24 22:19:17 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:19:39 [INFO]-Current testEngine.best_valid_performance 0.5787587675308659
# 2021-01-24 22:19:39 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:19:39 [INFO]-performance on validation at epoch 4
# 2021-01-24 22:19:39 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.587327  |
# |  1 | precision@10 | 0.564364  |
# |  2 | recall@10    | 0.0730644 |
# |  3 | map@10       | 0.0489427 |
# +----+--------------+-----------
# 2021-01-24 22:19:39 [INFO]-
# 2021-01-24 22:19:39 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:19:39 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:19:39 [INFO]-performance on testing at epoch 4
# 2021-01-24 22:19:39 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.582796  |
# |  1 | precision@10 | 0.561917  |
# |  2 | recall@10    | 0.0685899 |
# |  3 | map@10       | 0.0460209 |
# +----+--------------+-----------
# 2021-01-24 22:19:39 [INFO]-
# 2021-01-24 22:19:39 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:19:39 [INFO]-Execute [train_eval_worker] method costing 21135.92 ms
# 2021-01-24 22:19:53 [INFO]-[Training Epoch 5], log_like_loss 10.660549350082874 kl_loss: 13.60635270550847 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:19:53 [INFO]-Execute [train_an_epoch] method costing 35771.20 ms
#   3%|3         | 6/200 [03:14<1:44:44, 32.39s/it]Epoch 6 starts !
# 2021-01-24 22:19:54 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:15 [INFO]-Current testEngine.best_valid_performance 0.5873274692534111
# 2021-01-24 22:20:15 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:15 [INFO]-performance on validation at epoch 5
# 2021-01-24 22:20:15 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.593347  |
# |  1 | precision@10 | 0.569556  |
# |  2 | recall@10    | 0.0722983 |
# |  3 | map@10       | 0.0496486 |
# +----+--------------+-----------
# 2021-01-24 22:20:15 [INFO]-
# 2021-01-24 22:20:15 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:16 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:16 [INFO]-performance on testing at epoch 5
# 2021-01-24 22:20:16 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.587112  |
# |  1 | precision@10 | 0.565316  |
# |  2 | recall@10    | 0.069881  |
# |  3 | map@10       | 0.0466519 |
# +----+--------------+-----------
# 2021-01-24 22:20:16 [INFO]-
# 2021-01-24 22:20:16 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:16 [INFO]-Execute [train_eval_worker] method costing 21982.01 ms
# 2021-01-24 22:20:30 [INFO]-[Training Epoch 6], log_like_loss 10.398833574727178 kl_loss: 13.87632479146123 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:20:30 [INFO]-Execute [train_an_epoch] method costing 36271.50 ms
#   4%|3         | 7/200 [03:50<1:48:16, 33.66s/it]Epoch 7 starts !
# 2021-01-24 22:20:30 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:51 [INFO]-Current testEngine.best_valid_performance 0.593347186898656
# 2021-01-24 22:20:51 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:51 [INFO]-performance on validation at epoch 6
# 2021-01-24 22:20:51 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.599744  |
# |  1 | precision@10 | 0.574571  |
# |  2 | recall@10    | 0.073495  |
# |  3 | map@10       | 0.0503079 |
# +----+--------------+-----------
# 2021-01-24 22:20:51 [INFO]-
# 2021-01-24 22:20:51 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:51 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:51 [INFO]-performance on testing at epoch 6
# 2021-01-24 22:20:51 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.592406  |
# |  1 | precision@10 | 0.569237  |
# |  2 | recall@10    | 0.068705  |
# |  3 | map@10       | 0.0469783 |
# +----+--------------+-----------
# 2021-01-24 22:20:51 [INFO]-
# 2021-01-24 22:20:51 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:20:51 [INFO]-Execute [train_eval_worker] method costing 21313.39 ms
# 2021-01-24 22:21:07 [INFO]-[Training Epoch 7], log_like_loss 10.140295427292585 kl_loss: 14.001530066132545 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:21:07 [INFO]-Execute [train_an_epoch] method costing 36547.92 ms
#   4%|4         | 8/200 [04:27<1:50:47, 34.62s/it]Epoch 8 starts !
# 2021-01-24 22:21:07 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:21:29 [INFO]-Current testEngine.best_valid_performance 0.5997439185155959
# 2021-01-24 22:21:29 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:21:29 [INFO]-performance on validation at epoch 7
# 2021-01-24 22:21:29 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.605843  |
# |  1 | precision@10 | 0.582226  |
# |  2 | recall@10    | 0.0728711 |
# |  3 | map@10       | 0.050416  |
# +----+--------------+-----------
# 2021-01-24 22:21:29 [INFO]-
# 2021-01-24 22:21:29 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:21:29 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:21:29 [INFO]-performance on testing at epoch 7
# 2021-01-24 22:21:29 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.595909  |
# |  1 | precision@10 | 0.571242  |
# |  2 | recall@10    | 0.0690044 |
# |  3 | map@10       | 0.0471634 |
# +----+--------------+-----------
# 2021-01-24 22:21:29 [INFO]-
# 2021-01-24 22:21:29 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:21:29 [INFO]-Execute [train_eval_worker] method costing 21552.47 ms
# 2021-01-24 22:21:43 [INFO]-[Training Epoch 8], log_like_loss 9.851402686908841 kl_loss: 14.003352005034685 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:21:43 [INFO]-Execute [train_an_epoch] method costing 36212.34 ms
#   4%|4         | 9/200 [05:04<1:52:05, 35.21s/it]Epoch 9 starts !
# 2021-01-24 22:21:44 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:05 [INFO]-Current testEngine.best_valid_performance 0.6058430654426403
# 2021-01-24 22:22:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:05 [INFO]-performance on validation at epoch 8
# 2021-01-24 22:22:05 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.607892  |
# |  1 | precision@10 | 0.58271   |
# |  2 | recall@10    | 0.0738319 |
# |  3 | map@10       | 0.051174  |
# +----+--------------+-----------
# 2021-01-24 22:22:05 [INFO]-
# 2021-01-24 22:22:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:05 [INFO]-performance on testing at epoch 8
# 2021-01-24 22:22:05 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.596672  |
# |  1 | precision@10 | 0.573638  |
# |  2 | recall@10    | 0.0697668 |
# |  3 | map@10       | 0.0475206 |
# +----+--------------+-----------
# 2021-01-24 22:22:05 [INFO]-
# 2021-01-24 22:22:05 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:05 [INFO]-Execute [train_eval_worker] method costing 21497.26 ms
# 2021-01-24 22:22:19 [INFO]-[Training Epoch 9], log_like_loss 9.634870620444417 kl_loss: 13.984660863876343 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:22:19 [INFO]-Execute [train_an_epoch] method costing 35476.16 ms
#   5%|5         | 10/200 [05:40<1:52:03, 35.39s/it]Epoch 10 starts !
# 2021-01-24 22:22:19 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:41 [INFO]-Current testEngine.best_valid_performance 0.6078918364843549
# 2021-01-24 22:22:41 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:41 [INFO]-performance on validation at epoch 9
# 2021-01-24 22:22:41 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.608078  |
# |  1 | precision@10 | 0.58381   |
# |  2 | recall@10    | 0.0746389 |
# |  3 | map@10       | 0.051323  |
# +----+--------------+-----------
# 2021-01-24 22:22:41 [INFO]-
# 2021-01-24 22:22:41 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:41 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:41 [INFO]-performance on testing at epoch 9
# 2021-01-24 22:22:41 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.598015  |
# |  1 | precision@10 | 0.573246  |
# |  2 | recall@10    | 0.0688733 |
# |  3 | map@10       | 0.047586  |
# +----+--------------+-----------
# 2021-01-24 22:22:41 [INFO]-
# 2021-01-24 22:22:41 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:22:41 [INFO]-Execute [train_eval_worker] method costing 21580.94 ms
# 2021-01-24 22:22:55 [INFO]-[Training Epoch 10], log_like_loss 9.398842485621572 kl_loss: 13.878175098448992 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:22:55 [INFO]-Execute [train_an_epoch] method costing 36048.78 ms
#   6%|5         | 11/200 [06:16<1:52:26, 35.70s/it]Epoch 11 starts !
# 2021-01-24 22:22:56 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:17 [INFO]-Current testEngine.best_valid_performance 0.6080776499589038
# 2021-01-24 22:23:17 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:17 [INFO]-performance on validation at epoch 10
# 2021-01-24 22:23:17 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.609334  |
# |  1 | precision@10 | 0.584646  |
# |  2 | recall@10    | 0.075095  |
# |  3 | map@10       | 0.0510441 |
# +----+--------------+-----------
# 2021-01-24 22:23:17 [INFO]-
# 2021-01-24 22:23:17 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:17 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:17 [INFO]-performance on testing at epoch 10
# 2021-01-24 22:23:17 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.599435  |
# |  1 | precision@10 | 0.576078  |
# |  2 | recall@10    | 0.0696168 |
# |  3 | map@10       | 0.0481535 |
# +----+--------------+-----------
# 2021-01-24 22:23:17 [INFO]-
# 2021-01-24 22:23:17 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:17 [INFO]-Execute [train_eval_worker] method costing 21247.51 ms
# 2021-01-24 22:23:32 [INFO]-[Training Epoch 11], log_like_loss 9.170754039660096 kl_loss: 13.82910456880927 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:23:32 [INFO]-Execute [train_an_epoch] method costing 36272.29 ms
#   6%|6         | 12/200 [06:53<1:52:41, 35.96s/it]Epoch 12 starts !
# 2021-01-24 22:23:32 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:23:54 [INFO]-number of epochs that have no update 1
# 2021-01-24 22:23:54 [INFO]-Execute [train_eval_worker] method costing 21140.92 ms
# 2021-01-24 22:24:09 [INFO]-[Training Epoch 12], log_like_loss 8.982680704444647 kl_loss: 13.886418908834457 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:24:09 [INFO]-Execute [train_an_epoch] method costing 36189.04 ms
#   6%|6         | 13/200 [07:29<1:52:38, 36.14s/it]Epoch 13 starts !
# 2021-01-24 22:24:09 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:24:30 [INFO]-Current testEngine.best_valid_performance 0.6093341062100348
# 2021-01-24 22:24:30 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:24:30 [INFO]-performance on validation at epoch 12
# 2021-01-24 22:24:30 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.610083  |
# |  1 | precision@10 | 0.586318  |
# |  2 | recall@10    | 0.0755833 |
# |  3 | map@10       | 0.0511188 |
# +----+--------------+-----------
# 2021-01-24 22:24:30 [INFO]-
# 2021-01-24 22:24:30 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:24:30 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:24:30 [INFO]-performance on testing at epoch 12
# 2021-01-24 22:24:30 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.600579  |
# |  1 | precision@10 | 0.578039  |
# |  2 | recall@10    | 0.0679461 |
# |  3 | map@10       | 0.0473118 |
# +----+--------------+-----------
# 2021-01-24 22:24:30 [INFO]-
# 2021-01-24 22:24:30 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:24:30 [INFO]-Execute [train_eval_worker] method costing 21213.52 ms
# 2021-01-24 22:24:45 [INFO]-[Training Epoch 13], log_like_loss 8.761891312897205 kl_loss: 13.960555788129568 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:24:45 [INFO]-Execute [train_an_epoch] method costing 35831.29 ms
#   7%|7         | 14/200 [08:05<1:52:04, 36.15s/it]Epoch 14 starts !
# 2021-01-24 22:24:45 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:25:07 [INFO]-number of epochs that have no update 1
# 2021-01-24 22:25:07 [INFO]-Execute [train_eval_worker] method costing 21520.09 ms
# 2021-01-24 22:25:21 [INFO]-[Training Epoch 14], log_like_loss 8.583473823964596 kl_loss: 14.006951417773962 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:25:21 [INFO]-Execute [train_an_epoch] method costing 35952.21 ms
#   8%|7         | 15/200 [08:42<1:51:38, 36.21s/it]Epoch 15 starts !
# 2021-01-24 22:25:21 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:25:43 [INFO]-number of epochs that have no update 2
# 2021-01-24 22:25:43 [INFO]-Execute [train_eval_worker] method costing 21089.93 ms
# 2021-01-24 22:25:57 [INFO]-[Training Epoch 15], log_like_loss 8.38874083198607 kl_loss: 14.040323935449123 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:25:57 [INFO]-Execute [train_an_epoch] method costing 35398.23 ms
#   8%|8         | 16/200 [09:18<1:50:36, 36.07s/it]Epoch 16 starts !
# 2021-01-24 22:25:57 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:26:18 [INFO]-number of epochs that have no update 3
# 2021-01-24 22:26:18 [INFO]-Execute [train_eval_worker] method costing 21140.63 ms
# 2021-01-24 22:26:33 [INFO]-[Training Epoch 16], log_like_loss 8.221982229501009 kl_loss: 14.127301912754774 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:26:33 [INFO]-Execute [train_an_epoch] method costing 35606.33 ms
#   8%|8         | 17/200 [09:54<1:49:58, 36.06s/it]Epoch 17 starts !
# 2021-01-24 22:26:33 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:26:54 [INFO]-number of epochs that have no update 4
# 2021-01-24 22:26:54 [INFO]-Execute [train_eval_worker] method costing 21204.31 ms
# 2021-01-24 22:27:10 [INFO]-[Training Epoch 17], log_like_loss 8.061730805784464 kl_loss: 14.11086392775178 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:27:10 [INFO]-Execute [train_an_epoch] method costing 36697.32 ms
#   9%|9         | 18/200 [10:31<1:50:14, 36.34s/it]Epoch 18 starts !
# 2021-01-24 22:27:10 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:27:32 [INFO]-number of epochs that have no update 5
# 2021-01-24 22:27:32 [INFO]-Execute [train_eval_worker] method costing 21381.74 ms
# 2021-01-24 22:27:46 [INFO]-[Training Epoch 18], log_like_loss 7.892430720850825 kl_loss: 14.063440456986427 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:27:46 [INFO]-Execute [train_an_epoch] method costing 35839.32 ms
#  10%|9         | 19/200 [11:07<1:49:28, 36.29s/it]Epoch 19 starts !
# 2021-01-24 22:27:46 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:28:08 [INFO]-number of epochs that have no update 6
# 2021-01-24 22:28:08 [INFO]-Execute [train_eval_worker] method costing 21364.16 ms
# 2021-01-24 22:28:22 [INFO]-[Training Epoch 19], log_like_loss 7.753371367231011 kl_loss: 14.136444456875324 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:28:22 [INFO]-Execute [train_an_epoch] method costing 35678.57 ms
#  10%|#         | 20/200 [11:43<1:48:36, 36.20s/it]Epoch 20 starts !
# 2021-01-24 22:28:22 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:28:44 [INFO]-number of epochs that have no update 7
# 2021-01-24 22:28:44 [INFO]-Execute [train_eval_worker] method costing 21314.89 ms
# 2021-01-24 22:28:59 [INFO]-[Training Epoch 20], log_like_loss 7.624702641740441 kl_loss: 14.194979198276997 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:28:59 [INFO]-Execute [train_an_epoch] method costing 36079.43 ms
#  10%|#         | 21/200 [12:19<1:48:10, 36.26s/it]Epoch 21 starts !
# 2021-01-24 22:28:59 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:29:20 [INFO]-number of epochs that have no update 8
# 2021-01-24 22:29:20 [INFO]-Execute [train_eval_worker] method costing 21399.34 ms
# 2021-01-24 22:29:35 [INFO]-[Training Epoch 21], log_like_loss 7.497610339894891 kl_loss: 14.181329231709242 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:29:35 [INFO]-Execute [train_an_epoch] method costing 36439.33 ms
#  11%|#1        | 22/200 [12:56<1:48:00, 36.41s/it]Epoch 22 starts !
# 2021-01-24 22:29:36 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:29:57 [INFO]-number of epochs that have no update 9
# 2021-01-24 22:29:57 [INFO]-Execute [train_eval_worker] method costing 21149.95 ms
# 2021-01-24 22:30:11 [INFO]-[Training Epoch 22], log_like_loss 7.360948141664267 kl_loss: 14.13012433797121 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:30:11 [INFO]-Execute [train_an_epoch] method costing 35619.26 ms
#  12%|#1        | 23/200 [13:32<1:46:59, 36.27s/it]Epoch 23 starts !
# 2021-01-24 22:30:12 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:30:33 [INFO]-number of epochs that have no update 10
# 2021-01-24 22:30:33 [INFO]-Execute [train_eval_worker] method costing 21162.96 ms
# 2021-01-24 22:30:47 [INFO]-[Training Epoch 23], log_like_loss 7.231563284993172 kl_loss: 14.117747645825148 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:30:47 [INFO]-Execute [train_an_epoch] method costing 35883.30 ms
#  12%|#2        | 24/200 [14:08<1:46:20, 36.25s/it]Epoch 24 starts !
# 2021-01-24 22:30:48 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:31:09 [INFO]-number of epochs that have no update 11
# 2021-01-24 22:31:09 [INFO]-Execute [train_eval_worker] method costing 21144.88 ms
# 2021-01-24 22:31:24 [INFO]-[Training Epoch 24], log_like_loss 7.132789250463247 kl_loss: 14.091945055872202 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:31:24 [INFO]-Execute [train_an_epoch] method costing 35924.37 ms
#  12%|#2        | 25/200 [14:44<1:45:43, 36.25s/it]Epoch 25 starts !
# 2021-01-24 22:31:24 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:31:45 [INFO]-number of epochs that have no update 12
# 2021-01-24 22:31:45 [INFO]-Execute [train_eval_worker] method costing 21207.55 ms
# 2021-01-24 22:32:00 [INFO]-[Training Epoch 25], log_like_loss 7.0357113759964705 kl_loss: 14.128608662635088 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:32:00 [INFO]-Execute [train_an_epoch] method costing 35835.84 ms
#  13%|#3        | 26/200 [15:20<1:45:02, 36.22s/it]Epoch 26 starts !
# 2021-01-24 22:32:00 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:32:21 [INFO]-number of epochs that have no update 13
# 2021-01-24 22:32:21 [INFO]-Execute [train_eval_worker] method costing 21152.57 ms
# 2021-01-24 22:32:37 [INFO]-[Training Epoch 26], log_like_loss 6.929282885044813 kl_loss: 14.288723312318325 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:32:37 [INFO]-Execute [train_an_epoch] method costing 36439.13 ms
#  14%|#3        | 27/200 [15:57<1:44:53, 36.38s/it]Epoch 27 starts !
# 2021-01-24 22:32:37 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:32:58 [INFO]-number of epochs that have no update 14
# 2021-01-24 22:32:58 [INFO]-Execute [train_eval_worker] method costing 21210.92 ms
# 2021-01-24 22:33:13 [INFO]-[Training Epoch 27], log_like_loss 6.834634263068438 kl_loss: 14.175882034003735 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:33:13 [INFO]-Execute [train_an_epoch] method costing 36517.44 ms
#  14%|#4        | 28/200 [16:34<1:44:41, 36.52s/it]Epoch 28 starts !
# 2021-01-24 22:33:14 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:33:35 [INFO]-number of epochs that have no update 15
# 2021-01-24 22:33:35 [INFO]-Execute [train_eval_worker] method costing 21343.88 ms
# 2021-01-24 22:33:50 [INFO]-[Training Epoch 28], log_like_loss 6.763540931046009 kl_loss: 14.997361730784178 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:33:50 [INFO]-Execute [train_an_epoch] method costing 36517.25 ms
#  14%|#4        | 29/200 [17:11<1:44:21, 36.61s/it]Epoch 29 starts !
# 2021-01-24 22:33:51 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:34:12 [INFO]-number of epochs that have no update 16
# 2021-01-24 22:34:12 [INFO]-Execute [train_eval_worker] method costing 21225.16 ms
# 2021-01-24 22:34:25 [INFO]-[Training Epoch 29], log_like_loss 6.680850002914667 kl_loss: 15.342677149921656 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:34:25 [INFO]-Execute [train_an_epoch] method costing 34305.66 ms
#  15%|#5        | 30/200 [17:45<1:42:02, 36.02s/it]Epoch 30 starts !
# 2021-01-24 22:34:25 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:34:46 [INFO]-number of epochs that have no update 17
# 2021-01-24 22:34:46 [INFO]-Execute [train_eval_worker] method costing 21209.60 ms
# 2021-01-24 22:35:01 [INFO]-[Training Epoch 30], log_like_loss 6.601766269654036 kl_loss: 14.287542752921581 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:35:01 [INFO]-Execute [train_an_epoch] method costing 35852.65 ms
#  16%|#5        | 31/200 [18:22<1:41:34, 36.06s/it]Epoch 31 starts !
# 2021-01-24 22:35:01 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:35:23 [INFO]-number of epochs that have no update 18
# 2021-01-24 22:35:23 [INFO]-Execute [train_eval_worker] method costing 21521.08 ms
# 2021-01-24 22:35:38 [INFO]-[Training Epoch 31], log_like_loss 6.522178275510669 kl_loss: 14.18577666953206 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:35:38 [INFO]-Execute [train_an_epoch] method costing 36305.99 ms
#  16%|#6        | 32/200 [18:58<1:41:27, 36.23s/it]Epoch 32 starts !
# 2021-01-24 22:35:38 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:35:59 [INFO]-number of epochs that have no update 19
# 2021-01-24 22:35:59 [INFO]-Execute [train_eval_worker] method costing 21298.55 ms
# 2021-01-24 22:36:15 [INFO]-[Training Epoch 32], log_like_loss 6.459858763962984 kl_loss: 14.307068414986134 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:36:15 [INFO]-Execute [train_an_epoch] method costing 36789.70 ms
#  16%|#6        | 33/200 [19:35<1:41:35, 36.50s/it]Epoch 33 starts !
# 2021-01-24 22:36:15 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:36:36 [INFO]-number of epochs that have no update 20
# 2021-01-24 22:36:36 [INFO]-Execute [train_eval_worker] method costing 21209.80 ms
# 2021-01-24 22:36:51 [INFO]-[Training Epoch 33], log_like_loss 6.405021106824279 kl_loss: 14.215465612709522 alpha: 0.001 lr: 0.0005
# 2021-01-24 22:36:51 [INFO]-Execute [train_an_epoch] method costing 35412.62 ms
#  17%|#7        | 34/200 [20:11<1:40:21, 36.28s/it]Epoch 34 starts !
# 2021-01-24 22:36:51 [INFO]---------------------------------------------------------------------------------
# 2021-01-24 22:36:51 [INFO]-Early stop criterion triggered, no performance update for 20 times
#  17%|#7        | 34/200 [20:11<1:38:35, 35.64s/it]
# 2021-01-24 22:36:51 [INFO]-Program running time:1240 seconds
# {'valid_metric': 0.6100829853143107,
#  'model_save_dir': '/home/zm324/workspace/beta-recsys/checkpoints/VBCAR_default_20210124_221607_ldzury/vbcar.model'}
# 2021-01-24 22:37:10 [INFO]-number of epochs that have no update 21
# 2021-01-24 22:37:10 [INFO]-Execute [train_eval_worker] method costing 19220.62 ms

# %% [markdown]
# ### Model Tunning

# %%
from beta_rec.recommenders import SASRec
from beta_rec.datasets.movielens import Movielens_1m,Movielens_100k
from beta_rec.data.sequential_data import SequentialData

dataset = Movielens_100k()
split_dataset = dataset.load_leave_one_out(n_test=1)
data = SequentialData(split_dataset)


config = {"config_file": "./sasrec_default.json",
          "device":"gpu",
          "tune":True
         }
model = SASRec(config)
model.train(data)
